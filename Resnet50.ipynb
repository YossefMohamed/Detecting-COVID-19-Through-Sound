# %% [markdown]
# <a href="https://colab.research.google.com/github/YossefMohamed/Detecting-COVID-19-Through-Sound/blob/main/Resnet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras import Sequential,Model
from keras.layers import concatenate,Activation, Dense, Dropout, Conv2D, Flatten, MaxPooling2D, GlobalMaxPooling2D, GlobalAveragePooling1D, AveragePooling2D, Input, Add, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.models import model_from_json
from sklearn.metrics import roc_curve
from keras.utils import np_utils
from tqdm import tqdm
import pandas as pd
import numpy as np
import librosa 
import librosa.display
import pylab
import cv2
import os

# %%
# !git clone https://github.com/iiscleap/Coswara-Data.git
# Out:
# Cloning into 'Coswara-Data'...
# remote: Enumerating objects: 798, done.
# remote: Total 798 (delta 0), reused 0 (delta 0), pack-reused 798
# Receiving objects: 100% (798/798), 15.97 GiB | 58.79 MiB/s, done.
# Resolving deltas: 100% (310/310), done.
# Checking out files: 100% (202/202), done.

# %%
rt_dir = '/content/Coswara-Data'
import glob
for each in os.listdir(rt_dir):
    if os.path.isdir(os.path.join(rt_dir,each)) and each != '.git':
        print(each)
        # !cat {os.path.join(rt_dir, each,'')}*.tar.gz.* > {os.path.join(rt_dir, each,'')}combined_file.tar.gz
        # !tar -xzf {os.path.join(rt_dir, each,'')}combined_file.tar.gz -C {rt_dir}
subset = glob.glob('/content/Coswara-Data/*/*.tar.gz.*') + glob.glob('/content/Coswara-Data/*/combined_data.tar.gz')
[os.remove(x) for x in subset];
# Out:
# 20200814
# 20201221
# 20200901
# 20200820
# 20210714
# 20200525
# 20201031
# 20200720
# 20200505
# 20200604
# 20210523
# 20210914
# 20200413
# 20210830
# 20200424
# 20210618
# 20210816
# 20210930
# 20200911
# 20200430
# 20200707
# 20200919
# 20200419
# 20220116
# 20200502
# 20210630
# 20210406
# 20200504
# 20201012
# 20210426
# 20200930
# 20200416
# 20200415
# 20200803
# 20210507
# 20200417
# 20210206
# 20210603
# 20200418
# 20220224
# 20201130
# 20200824
# 20210419

# %%
# !wget https://zenodo.org/record/4048312/files/public_dataset.zip?download=1
# !mv public_dataset.zip?download=1 public_dataset.zip
# !unzip -q public_dataset.zip
# !mkdir 'custom_dataset'
# Out:
# --2022-05-21 14:10:42--  https://zenodo.org/record/4048312/files/public_dataset.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 951442487 (907M) [application/octet-stream]
# Saving to: ‘public_dataset.zip?download=1’
#
# public_dataset.zip? 100%[===================>] 907.37M  11.8MB/s    in 54s
#
# 2022-05-21 14:11:38 (16.8 MB/s) - ‘public_dataset.zip?download=1’ saved [951442487/951442487]

# %%
names   = ['ID','Fever/MP','ORC','STATUS','DIR','DataSet']
join_by = pd.read_csv('/content/Coswara-Data/combined_data.csv')

import glob
df_list = []
for path in tqdm(glob.glob('/content/Coswara-Data/*/*/cough-shallow.wav')):
  temp = pd.DataFrame(columns=['id','DIR'])
  temp['id'] = [path.split('/')[-2]]
  temp['DIR'] = [path]
  temp = pd.merge(left=temp,right=join_by,on='id',how='inner')

  temp['fomp']= (temp['fever']| temp['mp']).apply(int)
  temp['oths']= (temp['cld']|temp['asthma']|temp['cold']|temp['st']|temp['pneumonia']).apply(int)
  temp        = temp[['id','covid_status','DIR','fomp','oths']]
  df_list.append(temp.rename(columns={'id':'ID','covid_status':'STATUS','DIR':'DIR','fomp':'Fever/MP','oths':'ORC'}))
CosData1=pd.concat(df_list)
CosData1['DataSet'] = 'coswara'
CosData1.head()
# Out:
# 100%|██████████| 2745/2745 [00:26<00:00, 102.17it/s]
#                              ID                   STATUS  \
# 0  yWWeEGFFbQV2s7QqXUQjSrdp6573                  healthy
# 0  I11YsKcNytZ27XLyt5yKhxMyLZV2  no_resp_illness_exposed
# 0  5GwKvWfqLdU0p5udswzjmoFLEhr2  no_resp_illness_exposed
# 0  byVsWVHvkgc9Pkf4lUPOGSdZ0Vl2                  healthy
# 0  PNSX8UstjlY1mxA69mrklK5N2i32                  healthy
#
#                                                  DIR  Fever/MP  ORC  DataSet
# 0  /content/Coswara-Data/20200814/yWWeEGFFbQV2s7Q...         0    0  coswara
# 0  /content/Coswara-Data/20200814/I11YsKcNytZ27XL...         0    0  coswara
# 0  /content/Coswara-Data/20200814/5GwKvWfqLdU0p5u...         0    0  coswara
# 0  /content/Coswara-Data/20200814/byVsWVHvkgc9Pkf...         0    0  coswara
# 0  /content/Coswara-Data/20200814/PNSX8UstjlY1mxA...         0    0  coswara

# %%
CosData1['STATUS'].unique()
# Out:
# array(['healthy', 'no_resp_illness_exposed', 'positive_mild',
#        'resp_illness_not_identified', 'recovered_full',
#        'positive_moderate', 'positive_asymp', 'under_validation'],
#       dtype=object)

# %%
positive_mild = CosData1.loc[CosData1['STATUS']=='positive_mild']
positive_moderate    = CosData1.loc[CosData1['STATUS']=='positive_moderate']
positive_asymp = CosData1.loc[CosData1['STATUS']=='positive_asymp']

positive = pd.concat([positive_mild,positive_moderate,positive_asymp])

healthy = CosData1.loc[CosData1['STATUS']=='healthy']
resp_illness_not_identified = CosData1.loc[CosData1['STATUS']=='resp_illness_not_identified']
no_resp_illness_exposed = CosData1.loc[CosData1['STATUS']=='no_resp_illness_exposed']
recovered_full = CosData1.loc[CosData1['STATUS']=='recovered_full']

negative =  pd.concat([healthy,resp_illness_not_identified,no_resp_illness_exposed,recovered_full])

print(len(positive))
print(len(negative))

f_negative = negative.loc[negative['STATUS']!='COVID-19'][0:1500]
print(len(f_negative))
# Out:
# 681
# 1983
# 1500

# %%
coughvid  = '/content/public_dataset/'
custpath  = '/content/custom_dataset/' #Where mel spec images will be stored

VidData   = pd.read_csv(os.path.join(coughvid,'metadata_compiled.csv'),header=0)
VidData   = VidData.loc[VidData['cough_detected'] >= 0.9][['uuid','fever_muscle_pain','respiratory_condition','status']]
VidData.dropna(inplace=True)

extradata = VidData.loc[VidData['status']=='COVID-19']
notradata = VidData.loc[VidData['status']!='COVID-19']

TotData   = pd.concat([extradata,notradata],ignore_index= True)
TotData['DIR'] = coughvid + TotData['uuid'] + '.webm'
TotData['DataSet'] = 'coughvid'
TotData['fever_muscle_pain']    = TotData['fever_muscle_pain'].apply(int)
TotData['respiratory_condition']= TotData['respiratory_condition'].apply(int)
## TotData   = pd.concat([CosData,TotData.rename(columns={'uuid':'ID','status':'STATUS','fever_muscle_pain':'Fever/MP','respiratory_condition':'ORC'})])
TotData   = TotData.rename(columns={'uuid':'ID','status':'STATUS','fever_muscle_pain':'Fever/MP','respiratory_condition':'ORC'})
TotData   = TotData.sample(frac=1).reset_index(drop=True)
TotData.head()
# Out:
#                                      ID  Fever/MP  ORC   STATUS  \
# 0  3ba36da8-a4af-4dce-ad62-d3398d4c9cd5         0    0  healthy
# 1  5d85c3f9-38dc-4100-8ac8-7ac32baa0039         0    0  healthy
# 2  3f0ab307-e007-4ddf-bfb7-a7ec19a31988         0    0  healthy
# 3  045fd90f-c1ba-42e9-abda-2a85a9514377         0    0  healthy
# 4  84cbaecd-6e1b-4d31-a32d-8fda7a4de9c5         0    0  healthy
#
#                                                  DIR   DataSet
# 0  /content/public_dataset/3ba36da8-a4af-4dce-ad6...  coughvid
# 1  /content/public_dataset/5d85c3f9-38dc-4100-8ac...  coughvid
# 2  /content/public_dataset/3f0ab307-e007-4ddf-bfb...  coughvid
# 3  /content/public_dataset/045fd90f-c1ba-42e9-abd...  coughvid
# 4  /content/public_dataset/84cbaecd-6e1b-4d31-a32...  coughvid

# %%
covid_TotData = TotData[TotData["STATUS"] == "COVID-19" ]
#symptomatic_TotData = TotData[TotData["STATUS"] == "symptomatic" ][:490]
healthy_TotData = TotData[TotData["STATUS"] != "COVID-19" ][:975]

print(len(covid_TotData) , len(healthy_TotData))
covid_TotData.head()
# Out:
# 441 975
#                                       ID  Fever/MP  ORC    STATUS  \
# 10  09126c08-5214-4723-94f1-7b654464eac0         0    1  COVID-19
# 15  6ecde34e-2767-47b0-aef3-2828d4b181c7         0    0  COVID-19
# 17  7c0c7e95-4a6b-4d75-b46c-6cb8cf280094         0    0  COVID-19
# 32  7e3d9f84-ec39-4775-919b-fdab4aaac541         1    0  COVID-19
# 47  e389b2e1-e6a3-4b8d-a6f7-080890003015         0    0  COVID-19
#
#                                                   DIR   DataSet
# 10  /content/public_dataset/09126c08-5214-4723-94f...  coughvid
# 15  /content/public_dataset/6ecde34e-2767-47b0-aef...  coughvid
# 17  /content/public_dataset/7c0c7e95-4a6b-4d75-b46...  coughvid
# 32  /content/public_dataset/7e3d9f84-ec39-4775-919...  coughvid
# 47  /content/public_dataset/e389b2e1-e6a3-4b8d-a6f...  coughvid

# %%
#!pip install audiomentations
# !pip install audiomentations
# Out:
# Collecting audiomentations
#   Downloading audiomentations-0.24.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 3.2 MB/s
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from audiomentations) (1.21.6)
# Requirement already satisfied: librosa<0.10.0,>0.7.2 in /usr/local/lib/python3.7/dist-packages (from audiomentations) (0.8.1)
# Requirement already satisfied: scipy<2,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from audiomentations) (1.4.1)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (0.2.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (0.10.3.post1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (1.1.0)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (1.6.0)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (0.51.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (21.3)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (2.1.9)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (4.4.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (1.0.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa<0.10.0,>0.7.2->audiomentations) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa<0.10.0,>0.7.2->audiomentations) (57.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa<0.10.0,>0.7.2->audiomentations) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (2.23.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (1.4.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (3.0.4)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa<0.10.0,>0.7.2->audiomentations) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa<0.10.0,>0.7.2->audiomentations) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa<0.10.0,>0.7.2->audiomentations) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa<0.10.0,>0.7.2->audiomentations) (2.21)
# Installing collected packages: audiomentations
# Successfully installed audiomentations-0.24.0

# %%
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift
import soundfile as sf
import librosa
print(len(covid_TotData))
print(len(positive))
# Out:
# 441
# 681

# %%
augment = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.5),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
    Shift(min_fraction=-0.5, max_fraction=0.5, p=0.5),
])

os.makedirs("augmented_data_coswara")

# %%
#os.makedirs("augmented_data_coswara")

xx = pd.DataFrame()

for audio_file in  tqdm(positive["DIR"]):
  #print(audio_file.split("/")[-1] )
  try:
    samples, sr = librosa.load(audio_file)
    augmented_sample = augment(samples=samples, sample_rate=sr)
    sf.write("/content/augmented_data_coswara/" + audio_file.split("/")[-2] + ".wav", augmented_sample, sr) #write with wav extantion

    xx = xx.append(positive.loc[positive['ID'] == audio_file.split("/")[-2]])
    xx["DIR"].replace({ audio_file : "/content/augmented_data_coswara/" + audio_file.split("/")[-2] + ".wav"}, inplace=True)
    xx["ID"].replace({ audio_file.split("/")[-2] :  audio_file.split("/")[-2] + "AUG"}, inplace=True)

  except:
    print("\n File Not Found :))")
# Out:
#   5%|▍         | 31/681 [00:15<05:23,  2.01it/s]
#  File Not Found :))
#  86%|████████▌ | 587/681 [03:29<00:42,  2.23it/s]
#  File Not Found :))
#  99%|█████████▊| 671/681 [03:58<00:03,  2.51it/s]
#  File Not Found :))
# 100%|██████████| 681/681 [04:02<00:00,  2.81it/s]

# %%
os.makedirs("augmented_data_coughvid")

yy = pd.DataFrame()

for audio_file in  tqdm(covid_TotData["DIR"]):
  #print(audio_file.split("/")[-1] )
  try:
    samples, sr = librosa.load(audio_file)
    augmented_sample = augment(samples=samples, sample_rate=sr)
    sf.write("/content/augmented_data_coughvid/" + audio_file.split("/")[-1][0:-5] + ".wav", augmented_sample, sr) #write with wav extantion

    yy = yy.append(covid_TotData.loc[covid_TotData['ID'] == audio_file.split("/")[-1][0:-5]])
    yy["DIR"].replace({"/content/augmented_data_coughvid/"+ audio_file.split("/")[-1][0:-5] + ".webm": "/content/augmented_data_coughvid/" + audio_file.split("/")[-1][0:-5] + ".wav"}, inplace=True)
    yy["ID"].replace({ audio_file.split("/")[-1][0:-5] :  audio_file.split("/")[-1][0:-5] + "AUG"}, inplace=True)

  except:
    print("\n File Not Found :))")
# Out:
#   0%|          | 0/441 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 1/441 [00:01<14:35,  1.99s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 2/441 [00:02<09:34,  1.31s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 3/441 [00:03<07:54,  1.08s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 4/441 [00:04<06:30,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 5/441 [00:04<05:10,  1.40it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 6/441 [00:05<05:07,  1.41it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 7/441 [00:06<05:21,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 8/441 [00:07<06:43,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 9/441 [00:08<07:21,  1.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 10/441 [00:09<07:13,  1.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 11/441 [00:10<07:07,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 12/441 [00:11<06:36,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 13/441 [00:12<07:40,  1.08s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 14/441 [00:13<07:41,  1.08s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 15/441 [00:15<09:14,  1.30s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 16/441 [00:16<08:22,  1.18s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 17/441 [00:17<08:24,  1.19s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 18/441 [00:19<08:58,  1.27s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 19/441 [00:20<08:06,  1.15s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 20/441 [00:21<07:33,  1.08s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 21/441 [00:22<08:05,  1.16s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 22/441 [00:23<07:33,  1.08s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 23/441 [00:24<06:55,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 24/441 [00:25<06:58,  1.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▌         | 25/441 [00:25<05:53,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▌         | 26/441 [00:25<04:46,  1.45it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▌         | 27/441 [00:26<05:00,  1.38it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▋         | 28/441 [00:27<05:36,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 29/441 [00:28<05:20,  1.29it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 30/441 [00:29<05:06,  1.34it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 31/441 [00:30<05:39,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 32/441 [00:30<05:33,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 33/441 [00:31<05:31,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 34/441 [00:32<06:10,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 35/441 [00:33<05:29,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 36/441 [00:33<04:44,  1.42it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 37/441 [00:35<05:30,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▊         | 38/441 [00:35<05:28,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▉         | 39/441 [00:36<05:50,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▉         | 40/441 [00:37<05:09,  1.29it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▉         | 41/441 [00:38<05:55,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|▉         | 42/441 [00:39<06:31,  1.02it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|▉         | 43/441 [00:40<05:48,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|▉         | 44/441 [00:41<05:31,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|█         | 45/441 [00:41<05:16,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|█         | 46/441 [00:42<04:55,  1.33it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█         | 47/441 [00:43<05:37,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█         | 48/441 [00:44<05:29,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█         | 49/441 [00:45<06:01,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█▏        | 50/441 [00:46<05:29,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 51/441 [00:46<05:26,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 52/441 [00:48<05:52,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 53/441 [00:48<05:36,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 54/441 [00:49<05:13,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 55/441 [00:50<04:57,  1.30it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 56/441 [00:51<05:45,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 57/441 [00:52<05:19,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 58/441 [00:52<04:36,  1.38it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 59/441 [00:53<04:11,  1.52it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▎        | 60/441 [00:54<04:56,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▍        | 61/441 [00:54<04:42,  1.34it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▍        | 62/441 [00:55<04:32,  1.39it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▍        | 63/441 [00:56<04:39,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▍        | 64/441 [00:57<05:05,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▍        | 65/441 [00:58<05:13,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▍        | 66/441 [00:58<04:32,  1.38it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▌        | 67/441 [00:59<05:07,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▌        | 68/441 [01:00<04:59,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▌        | 69/441 [01:01<05:15,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▌        | 70/441 [01:02<05:03,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▌        | 71/441 [01:03<05:23,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▋        | 72/441 [01:03<05:02,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 73/441 [01:04<05:43,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 74/441 [01:05<05:48,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 75/441 [01:07<06:10,  1.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 76/441 [01:07<04:32,  1.34it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  File Not Found :))
#  17%|█▋        | 77/441 [01:08<04:59,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 78/441 [01:09<05:18,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 79/441 [01:09<05:08,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 80/441 [01:10<04:30,  1.34it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 81/441 [01:11<05:04,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▊        | 82/441 [01:12<04:57,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▉        | 83/441 [01:13<05:14,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▉        | 84/441 [01:14<04:51,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▉        | 85/441 [01:14<04:03,  1.46it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|█▉        | 86/441 [01:15<04:06,  1.44it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|█▉        | 87/441 [01:15<04:07,  1.43it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|█▉        | 88/441 [01:16<04:38,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|██        | 89/441 [01:17<04:27,  1.32it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|██        | 90/441 [01:18<05:11,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██        | 91/441 [01:19<05:21,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██        | 92/441 [01:20<04:52,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██        | 93/441 [01:21<05:07,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██▏       | 94/441 [01:22<04:46,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 95/441 [01:23<05:22,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 96/441 [01:23<04:57,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 97/441 [01:24<05:13,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 98/441 [01:25<04:19,  1.32it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 99/441 [01:26<04:24,  1.29it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 100/441 [01:27<04:49,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 101/441 [01:27<04:24,  1.29it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 102/441 [01:28<05:02,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 103/441 [01:29<04:46,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▎       | 104/441 [01:29<03:50,  1.46it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 105/441 [01:30<03:52,  1.45it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 106/441 [01:31<04:25,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 107/441 [01:32<03:39,  1.52it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 108/441 [01:32<03:59,  1.39it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▍       | 109/441 [01:33<03:56,  1.40it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▍       | 110/441 [01:34<04:31,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▌       | 111/441 [01:35<04:26,  1.24it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▌       | 112/441 [01:36<04:23,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▌       | 113/441 [01:36<04:01,  1.36it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▌       | 114/441 [01:37<03:50,  1.42it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▌       | 115/441 [01:38<03:45,  1.44it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▋       | 116/441 [01:39<04:19,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 117/441 [01:40<04:41,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 118/441 [01:41<04:55,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 119/441 [01:41<04:07,  1.30it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 120/441 [01:42<03:50,  1.40it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 121/441 [01:42<03:40,  1.45it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 122/441 [01:43<03:39,  1.46it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 123/441 [01:44<04:09,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 124/441 [01:45<04:10,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 125/441 [01:46<04:11,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▊       | 126/441 [01:46<03:49,  1.37it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 127/441 [01:47<03:29,  1.50it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 128/441 [01:48<03:40,  1.42it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 129/441 [01:48<03:50,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 130/441 [01:49<04:21,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|██▉       | 131/441 [01:51<04:47,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|██▉       | 132/441 [01:51<04:33,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|███       | 133/441 [01:52<04:30,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|███       | 134/441 [01:53<04:24,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 135/441 [01:54<04:07,  1.24it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 136/441 [01:55<04:05,  1.24it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 137/441 [01:55<03:52,  1.31it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███▏      | 138/441 [01:56<03:44,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 139/441 [01:57<03:39,  1.37it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 140/441 [01:57<03:43,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 141/441 [01:58<04:13,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 142/441 [01:59<04:07,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 143/441 [02:00<04:02,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 144/441 [02:01<04:23,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 145/441 [02:02<04:34,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 146/441 [02:03<04:43,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 147/441 [02:04<04:14,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▎      | 148/441 [02:04<03:56,  1.24it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 149/441 [02:05<03:43,  1.31it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 150/441 [02:06<03:16,  1.48it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 151/441 [02:07<03:48,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 152/441 [02:08<04:03,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▍      | 153/441 [02:08<03:50,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▍      | 154/441 [02:09<04:15,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▌      | 155/441 [02:11<04:37,  1.03it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▌      | 156/441 [02:11<04:22,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▌      | 157/441 [02:12<03:48,  1.24it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▌      | 158/441 [02:13<03:37,  1.30it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▌      | 159/441 [02:13<03:26,  1.37it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▋      | 160/441 [02:14<03:57,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 161/441 [02:15<03:36,  1.29it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 162/441 [02:16<03:25,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 163/441 [02:16<03:20,  1.39it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 164/441 [02:18<03:59,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 165/441 [02:18<03:39,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 166/441 [02:19<03:24,  1.34it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 167/441 [02:19<03:18,  1.38it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 168/441 [02:20<03:04,  1.48it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 169/441 [02:21<03:41,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 170/441 [02:22<04:03,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 171/441 [02:23<03:48,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 172/441 [02:23<03:17,  1.36it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 173/441 [02:25<03:48,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 174/441 [02:25<03:15,  1.37it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  40%|███▉      | 175/441 [02:26<03:34,  1.24it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  40%|███▉      | 176/441 [02:27<03:20,  1.32it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  40%|████      | 177/441 [02:28<03:37,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  40%|████      | 178/441 [02:29<03:59,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  41%|████      | 179/441 [02:30<03:50,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  41%|████      | 180/441 [02:30<03:24,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  41%|████      | 181/441 [02:31<03:15,  1.33it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  41%|████▏     | 182/441 [02:32<03:41,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  41%|████▏     | 183/441 [02:33<03:57,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  42%|████▏     | 184/441 [02:34<03:43,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  42%|████▏     | 185/441 [02:35<04:03,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  42%|████▏     | 186/441 [02:36<03:53,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  42%|████▏     | 187/441 [02:37<04:07,  1.02it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  43%|████▎     | 188/441 [02:37<03:03,  1.38it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  File Not Found :))
#  43%|████▎     | 189/441 [02:38<03:04,  1.36it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  43%|████▎     | 190/441 [02:38<02:41,  1.55it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  43%|████▎     | 191/441 [02:39<02:44,  1.52it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  44%|████▎     | 192/441 [02:40<03:24,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  44%|████▍     | 193/441 [02:40<02:53,  1.43it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  44%|████▍     | 194/441 [02:41<02:36,  1.58it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  44%|████▍     | 195/441 [02:42<03:14,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  44%|████▍     | 196/441 [02:43<03:43,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  45%|████▍     | 197/441 [02:44<03:52,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  45%|████▍     | 198/441 [02:45<03:33,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  45%|████▌     | 199/441 [02:46<03:54,  1.03it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  45%|████▌     | 200/441 [02:47<03:42,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  85%|████████▌ | 375/441 [05:05<00:48,  1.36it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  85%|████████▌ | 376/441 [05:06<00:46,  1.41it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  85%|████████▌ | 377/441 [05:07<00:52,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  86%|████████▌ | 378/441 [05:08<00:44,  1.41it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  86%|████████▌ | 379/441 [05:09<00:48,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  86%|████████▌ | 380/441 [05:09<00:47,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  86%|████████▋ | 381/441 [05:10<00:46,  1.29it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  87%|████████▋ | 382/441 [05:11<00:42,  1.40it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  87%|████████▋ | 383/441 [05:12<00:48,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  87%|████████▋ | 384/441 [05:13<00:51,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  87%|████████▋ | 385/441 [05:13<00:41,  1.34it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  88%|████████▊ | 386/441 [05:14<00:34,  1.60it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  88%|████████▊ | 387/441 [05:14<00:33,  1.62it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  88%|████████▊ | 388/441 [05:15<00:39,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  88%|████████▊ | 389/441 [05:16<00:38,  1.36it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  88%|████████▊ | 390/441 [05:17<00:41,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  89%|████████▊ | 391/441 [05:18<00:39,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  89%|████████▉ | 392/441 [05:19<00:42,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  89%|████████▉ | 393/441 [05:20<00:42,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  89%|████████▉ | 394/441 [05:20<00:38,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  90%|████████▉ | 395/441 [05:21<00:32,  1.43it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  90%|████████▉ | 396/441 [05:22<00:35,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  90%|█████████ | 397/441 [05:23<00:38,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  90%|█████████ | 398/441 [05:24<00:35,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  90%|█████████ | 399/441 [05:25<00:37,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  91%|█████████ | 400/441 [05:26<00:36,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  91%|█████████ | 401/441 [05:26<00:34,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  91%|█████████ | 402/441 [05:27<00:32,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  91%|█████████▏| 403/441 [05:28<00:30,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  92%|█████████▏| 404/441 [05:29<00:32,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  92%|█████████▏| 405/441 [05:30<00:29,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  92%|█████████▏| 406/441 [05:31<00:31,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  92%|█████████▏| 407/441 [05:32<00:32,  1.03it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  93%|█████████▎| 408/441 [05:33<00:30,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  93%|█████████▎| 409/441 [05:33<00:27,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  93%|█████████▎| 410/441 [05:34<00:26,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  93%|█████████▎| 411/441 [05:35<00:28,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  93%|█████████▎| 412/441 [05:36<00:26,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  94%|█████████▎| 413/441 [05:37<00:26,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  94%|█████████▍| 414/441 [05:38<00:24,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  94%|█████████▍| 415/441 [05:38<00:17,  1.49it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  File Not Found :))
#  94%|█████████▍| 416/441 [05:39<00:16,  1.50it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  95%|█████████▍| 417/441 [05:40<00:19,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  95%|█████████▍| 418/441 [05:40<00:16,  1.38it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  95%|█████████▌| 419/441 [05:41<00:17,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  95%|█████████▌| 420/441 [05:42<00:15,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  95%|█████████▌| 421/441 [05:42<00:12,  1.59it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  96%|█████████▌| 422/441 [05:43<00:14,  1.32it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  96%|█████████▌| 423/441 [05:44<00:14,  1.24it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  96%|█████████▌| 424/441 [05:45<00:13,  1.30it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  96%|█████████▋| 425/441 [05:46<00:11,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  97%|█████████▋| 426/441 [05:47<00:12,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  97%|█████████▋| 427/441 [05:48<00:13,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  97%|█████████▋| 428/441 [05:49<00:11,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  97%|█████████▋| 429/441 [05:50<00:11,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  98%|█████████▊| 430/441 [05:50<00:08,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  98%|█████████▊| 431/441 [05:51<00:08,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  98%|█████████▊| 432/441 [05:52<00:07,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  98%|█████████▊| 433/441 [05:53<00:06,  1.30it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  98%|█████████▊| 434/441 [05:53<00:04,  1.43it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  99%|█████████▊| 435/441 [05:54<00:04,  1.38it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  99%|█████████▉| 436/441 [05:55<00:03,  1.39it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  99%|█████████▉| 437/441 [05:56<00:03,  1.24it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  99%|█████████▉| 438/441 [05:56<00:02,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# 100%|█████████▉| 439/441 [05:57<00:01,  1.31it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# 100%|█████████▉| 440/441 [05:58<00:00,  1.36it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# 100%|██████████| 441/441 [05:59<00:00,  1.23it/s]

# %%
covid_TotData.head()
# Out:
#                                       ID  Fever/MP  ORC    STATUS  \
# 10  09126c08-5214-4723-94f1-7b654464eac0         0    1  COVID-19
# 15  6ecde34e-2767-47b0-aef3-2828d4b181c7         0    0  COVID-19
# 17  7c0c7e95-4a6b-4d75-b46c-6cb8cf280094         0    0  COVID-19
# 32  7e3d9f84-ec39-4775-919b-fdab4aaac541         1    0  COVID-19
# 47  e389b2e1-e6a3-4b8d-a6f7-080890003015         0    0  COVID-19
#
#                                                   DIR   DataSet
# 10  /content/public_dataset/09126c08-5214-4723-94f...  coughvid
# 15  /content/public_dataset/6ecde34e-2767-47b0-aef...  coughvid
# 17  /content/public_dataset/7c0c7e95-4a6b-4d75-b46...  coughvid
# 32  /content/public_dataset/7e3d9f84-ec39-4775-919...  coughvid
# 47  /content/public_dataset/e389b2e1-e6a3-4b8d-a6f...  coughvid

# %%
healthy_TotData.head()
# Out:
#                                      ID  Fever/MP  ORC   STATUS  \
# 0  3ba36da8-a4af-4dce-ad62-d3398d4c9cd5         0    0  healthy
# 1  5d85c3f9-38dc-4100-8ac8-7ac32baa0039         0    0  healthy
# 2  3f0ab307-e007-4ddf-bfb7-a7ec19a31988         0    0  healthy
# 3  045fd90f-c1ba-42e9-abda-2a85a9514377         0    0  healthy
# 4  84cbaecd-6e1b-4d31-a32d-8fda7a4de9c5         0    0  healthy
#
#                                                  DIR   DataSet
# 0  /content/public_dataset/3ba36da8-a4af-4dce-ad6...  coughvid
# 1  /content/public_dataset/5d85c3f9-38dc-4100-8ac...  coughvid
# 2  /content/public_dataset/3f0ab307-e007-4ddf-bfb...  coughvid
# 3  /content/public_dataset/045fd90f-c1ba-42e9-abd...  coughvid
# 4  /content/public_dataset/84cbaecd-6e1b-4d31-a32...  coughvid

# %%
yy.head()
# Out:
#                                          ID  Fever/MP  ORC    STATUS  \
# 10  09126c08-5214-4723-94f1-7b654464eac0AUG         0    1  COVID-19
# 15  6ecde34e-2767-47b0-aef3-2828d4b181c7AUG         0    0  COVID-19
# 17  7c0c7e95-4a6b-4d75-b46c-6cb8cf280094AUG         0    0  COVID-19
# 32  7e3d9f84-ec39-4775-919b-fdab4aaac541AUG         1    0  COVID-19
# 47  e389b2e1-e6a3-4b8d-a6f7-080890003015AUG         0    0  COVID-19
#
#                                                   DIR   DataSet
# 10  /content/public_dataset/09126c08-5214-4723-94f...  coughvid
# 15  /content/public_dataset/6ecde34e-2767-47b0-aef...  coughvid
# 17  /content/public_dataset/7c0c7e95-4a6b-4d75-b46...  coughvid
# 32  /content/public_dataset/7e3d9f84-ec39-4775-919...  coughvid
# 47  /content/public_dataset/e389b2e1-e6a3-4b8d-a6f...  coughvid

# %%
xx.head()
# Out:
#                                 ID         STATUS  \
# 0  ZaeW7vuikQgf7984JVqXYOtUQMs2AUG  positive_mild
# 0  quF8xZxqK8NnszkwktXovmZ9fBT2AUG  positive_mild
# 0  CUCqq4q5SQa3fDkpraekej7fNza2AUG  positive_mild
# 0  oIy4hushZORMcftMVIAxabN1QZd2AUG  positive_mild
# 0  ZpsUydPUXygszeJSVtTFjbsqoNQ2AUG  positive_mild
#
#                                                  DIR  Fever/MP  ORC  DataSet
# 0  /content/augmented_data_coswara/ZaeW7vuikQgf79...         0    0  coswara
# 0  /content/augmented_data_coswara/quF8xZxqK8Nnsz...         0    0  coswara
# 0  /content/augmented_data_coswara/CUCqq4q5SQa3fD...         0    0  coswara
# 0  /content/augmented_data_coswara/oIy4hushZORMcf...         0    0  coswara
# 0  /content/augmented_data_coswara/ZpsUydPUXygsze...         1    1  coswara

# %%
positive.head()
# Out:
#                              ID         STATUS  \
# 0  ZaeW7vuikQgf7984JVqXYOtUQMs2  positive_mild
# 0  quF8xZxqK8NnszkwktXovmZ9fBT2  positive_mild
# 0  CUCqq4q5SQa3fDkpraekej7fNza2  positive_mild
# 0  oIy4hushZORMcftMVIAxabN1QZd2  positive_mild
# 0  ZpsUydPUXygszeJSVtTFjbsqoNQ2  positive_mild
#
#                                                  DIR  Fever/MP  ORC  DataSet
# 0  /content/Coswara-Data/20200814/ZaeW7vuikQgf798...         0    0  coswara
# 0  /content/Coswara-Data/20201221/quF8xZxqK8Nnszk...         0    0  coswara
# 0  /content/Coswara-Data/20201221/CUCqq4q5SQa3fDk...         0    0  coswara
# 0  /content/Coswara-Data/20201221/oIy4hushZORMcft...         0    0  coswara
# 0  /content/Coswara-Data/20201221/ZpsUydPUXygszeJ...         1    1  coswara

# %%
f_negative.head()
# Out:
#                              ID   STATUS  \
# 0  yWWeEGFFbQV2s7QqXUQjSrdp6573  healthy
# 0  byVsWVHvkgc9Pkf4lUPOGSdZ0Vl2  healthy
# 0  PNSX8UstjlY1mxA69mrklK5N2i32  healthy
# 0  ekXeaNBZYgZvh7mpGGwDQR4Jlwv2  healthy
# 0  QLfHliTV2YMbuC5y06vcclyWdEF2  healthy
#
#                                                  DIR  Fever/MP  ORC  DataSet
# 0  /content/Coswara-Data/20200814/yWWeEGFFbQV2s7Q...         0    0  coswara
# 0  /content/Coswara-Data/20200814/byVsWVHvkgc9Pkf...         0    0  coswara
# 0  /content/Coswara-Data/20200814/PNSX8UstjlY1mxA...         0    0  coswara
# 0  /content/Coswara-Data/20200814/ekXeaNBZYgZvh7m...         0    0  coswara
# 0  /content/Coswara-Data/20200814/QLfHliTV2YMbuC5...         0    0  coswara

# %% [markdown]
# ## creat datamerge to put all data in thet

# %%
datamerge = pd.concat([covid_TotData,healthy_TotData,yy,xx,positive,f_negative])

# %%
print(len(datamerge))
# Out:
# 4709

# %%
def feature_extractor(row):

  name     = row[-6]
  try:
    audio,sr = librosa.load(row[-2])
    #For MFCCS 
    mfccs    = librosa.feature.mfcc(y=audio,sr=22050, n_mfcc=13)
    mfccsscaled = np.mean(mfccs.T,axis=0)
    
    #Mel Spectogram
    pylab.axis('off') # no axis
    pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[])
    melspec  = librosa.feature.melspectrogram(y=audio,sr=sr)
    s_db     = librosa.power_to_db(melspec, ref=np.max)
    librosa.display.specshow(s_db)

    savepath = os.path.join(custpath,name+'.png')
    pylab.savefig(savepath, bbox_inches=None, pad_inches=0)
    pylab.close()
  except:
    print('File cannot open')
    return None,None
   # return mfccsscaled

  return mfccsscaled,savepath

# %%
features = []
diagnoses= []
imgpaths = []

# train
for row in tqdm(datamerge.values):
  mfccs,savepath  = feature_extractor(row)
  features.append(mfccs)
  imgpaths.append(savepath)
  diagnoses.append([row[-5],row[-4]])
# Out:
#   0%|          | 0/4709 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 1/4709 [00:00<1:14:22,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 2/4709 [00:01<1:11:32,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 3/4709 [00:02<1:09:40,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 4/4709 [00:03<59:41,  1.31it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 5/4709 [00:03<50:02,  1.57it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 6/4709 [00:04<57:30,  1.36it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 7/4709 [00:05<1:02:39,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 8/4709 [00:06<1:05:37,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 9/4709 [00:07<1:07:38,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 10/4709 [00:08<1:08:47,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 11/4709 [00:09<1:08:22,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 12/4709 [00:10<1:07:50,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 13/4709 [00:10<1:07:37,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 14/4709 [00:11<1:07:58,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 15/4709 [00:12<1:08:04,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 16/4709 [00:13<1:08:16,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 17/4709 [00:14<1:08:22,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 18/4709 [00:15<1:08:13,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 19/4709 [00:16<1:08:59,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 20/4709 [00:17<1:14:52,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 21/4709 [00:18<1:13:06,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 22/4709 [00:19<1:11:53,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 23/4709 [00:19<1:10:56,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 24/4709 [00:20<1:10:27,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 25/4709 [00:21<1:00:49,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 26/4709 [00:21<51:00,  1.53it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 27/4709 [00:22<56:17,  1.39it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 28/4709 [00:23<59:34,  1.31it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 29/4709 [00:24<1:02:14,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 30/4709 [00:25<1:04:23,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 31/4709 [00:26<1:05:54,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 32/4709 [00:26<1:07:06,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 33/4709 [00:27<1:08:45,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 34/4709 [00:28<1:08:58,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 35/4709 [00:29<1:01:24,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 36/4709 [00:29<57:31,  1.35it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 37/4709 [00:30<1:00:47,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 38/4709 [00:31<1:02:49,  1.24it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 39/4709 [00:32<1:04:17,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 40/4709 [00:33<1:01:30,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 41/4709 [00:34<1:04:00,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 42/4709 [00:35<1:05:32,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 43/4709 [00:35<59:18,  1.31it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 44/4709 [00:36<56:49,  1.37it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 45/4709 [00:37<55:51,  1.39it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 46/4709 [00:37<52:21,  1.48it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 47/4709 [00:38<57:34,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 48/4709 [00:39<1:01:06,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 49/4709 [00:40<1:03:51,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 50/4709 [00:40<58:46,  1.32it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 51/4709 [00:41<1:02:00,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 52/4709 [00:42<1:03:38,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 53/4709 [00:43<1:04:42,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 54/4709 [00:44<1:05:35,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 55/4709 [00:45<1:06:20,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 56/4709 [00:46<1:07:31,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 57/4709 [00:46<1:05:30,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 58/4709 [00:47<1:00:52,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 59/4709 [00:48<58:40,  1.32it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 60/4709 [00:49<1:01:27,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 61/4709 [00:50<1:03:39,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 62/4709 [00:50<1:04:35,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 63/4709 [00:51<1:05:54,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 64/4709 [00:52<1:13:17,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 65/4709 [00:53<1:10:22,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 66/4709 [00:54<1:02:48,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 67/4709 [00:55<1:04:39,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 68/4709 [00:56<1:05:35,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 69/4709 [00:57<1:06:41,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 70/4709 [00:57<1:02:53,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 71/4709 [00:58<1:05:38,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 72/4709 [00:59<1:07:53,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 73/4709 [01:00<1:09:26,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 74/4709 [01:01<1:10:25,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 75/4709 [01:02<1:10:53,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 76/4709 [01:02<53:23,  1.45it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# File cannot open
#   2%|▏         | 77/4709 [01:03<59:06,  1.31it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 78/4709 [01:04<1:03:17,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 79/4709 [01:05<1:05:35,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 80/4709 [01:05<58:31,  1.32it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 81/4709 [01:06<1:02:41,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 82/4709 [01:07<1:04:24,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 83/4709 [01:08<1:06:34,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 84/4709 [01:09<1:05:12,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 85/4709 [01:10<58:27,  1.32it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 86/4709 [01:11<1:02:44,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 87/4709 [01:11<1:00:11,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 88/4709 [01:12<1:03:52,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 89/4709 [01:13<1:06:28,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 90/4709 [01:14<1:08:31,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 91/4709 [01:15<1:09:36,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 92/4709 [01:16<1:04:15,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 93/4709 [01:17<1:07:18,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 94/4709 [01:18<1:09:17,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 95/4709 [01:19<1:10:44,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 96/4709 [01:20<1:11:52,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 97/4709 [01:21<1:12:38,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 98/4709 [01:21<1:04:31,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 99/4709 [01:22<1:06:36,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 100/4709 [01:23<1:07:34,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 101/4709 [01:24<1:03:52,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 102/4709 [01:25<1:06:28,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 103/4709 [01:25<1:06:36,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 104/4709 [01:26<56:54,  1.35it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 105/4709 [01:27<1:00:53,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 106/4709 [01:28<1:03:29,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 107/4709 [01:28<56:47,  1.35it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 108/4709 [01:29<57:39,  1.33it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 109/4709 [01:30<1:01:56,  1.24it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 110/4709 [01:31<1:05:16,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 111/4709 [01:32<1:07:53,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 112/4709 [01:33<1:09:20,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 113/4709 [01:33<1:02:33,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 114/4709 [01:34<1:05:11,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 115/4709 [01:35<1:07:26,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 116/4709 [01:36<1:09:01,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 117/4709 [01:37<1:09:59,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 118/4709 [01:38<1:10:46,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 119/4709 [01:39<1:04:28,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 120/4709 [01:40<1:12:45,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 121/4709 [01:41<1:08:09,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 122/4709 [01:42<1:09:13,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 123/4709 [01:43<1:10:06,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 124/4709 [01:44<1:10:24,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 125/4709 [01:45<1:11:02,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 126/4709 [01:45<1:03:55,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 127/4709 [01:46<1:02:39,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 128/4709 [01:47<1:05:20,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 129/4709 [01:48<1:07:34,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 130/4709 [01:49<1:08:50,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 131/4709 [01:50<1:09:58,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 132/4709 [01:51<1:10:41,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 133/4709 [01:51<1:07:01,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 134/4709 [01:52<1:05:43,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 135/4709 [01:53<1:08:59,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 136/4709 [01:54<1:10:24,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 137/4709 [01:55<1:12:02,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 138/4709 [01:56<1:12:53,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 139/4709 [01:57<1:11:40,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 140/4709 [01:58<1:11:46,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 141/4709 [01:59<1:12:29,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 142/4709 [02:00<1:12:24,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 143/4709 [02:01<1:12:26,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 144/4709 [02:02<1:12:03,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 145/4709 [02:03<1:12:45,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 146/4709 [02:04<1:13:01,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 147/4709 [02:05<1:07:53,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 148/4709 [02:06<1:09:38,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 149/4709 [02:07<1:10:06,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 150/4709 [02:07<1:01:39,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 151/4709 [02:08<1:05:03,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 152/4709 [02:09<1:07:50,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 153/4709 [02:10<1:08:32,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 154/4709 [02:11<1:10:20,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 155/4709 [02:12<1:11:36,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 156/4709 [02:13<1:12:12,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 157/4709 [02:14<1:07:44,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 158/4709 [02:15<1:09:34,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 159/4709 [02:15<1:04:34,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 160/4709 [02:16<1:07:10,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 161/4709 [02:17<1:05:03,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 162/4709 [02:18<1:04:32,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 163/4709 [02:19<1:07:14,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 164/4709 [02:20<1:09:35,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 165/4709 [02:21<1:06:09,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 166/4709 [02:21<1:02:10,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 167/4709 [02:22<1:05:54,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 168/4709 [02:23<1:03:17,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 169/4709 [02:24<1:07:03,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 170/4709 [02:25<1:09:13,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 171/4709 [02:26<1:11:19,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 172/4709 [02:27<1:05:14,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 173/4709 [02:28<1:08:30,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 174/4709 [02:28<1:04:11,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 175/4709 [02:29<1:07:36,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 176/4709 [02:30<1:04:16,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 177/4709 [02:31<1:07:11,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 178/4709 [02:32<1:09:49,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 179/4709 [02:33<1:11:53,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 180/4709 [02:34<1:07:52,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 181/4709 [02:35<1:10:04,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 182/4709 [02:36<1:10:57,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 183/4709 [02:37<1:12:15,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 184/4709 [02:38<1:12:10,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 185/4709 [02:39<1:12:56,  1.03it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 186/4709 [02:40<1:13:46,  1.02it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 187/4709 [02:41<1:14:33,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 188/4709 [02:41<57:13,  1.32it/s]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 189/4709 [02:42<57:08,  1.32it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 190/4709 [02:43<1:05:56,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 191/4709 [02:44<1:08:48,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 192/4709 [02:45<1:11:03,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 193/4709 [02:46<1:03:17,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 194/4709 [02:46<59:30,  1.26it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 195/4709 [02:47<1:03:20,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 196/4709 [02:48<1:05:55,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 197/4709 [02:49<1:07:45,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 198/4709 [02:50<1:09:54,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
# ...
#  38%|███▊      | 1794/4709 [38:32<1:31:47,  1.89s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1795/4709 [38:34<1:25:52,  1.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1796/4709 [38:35<1:22:36,  1.70s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1797/4709 [38:37<1:24:47,  1.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1798/4709 [38:39<1:27:18,  1.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1799/4709 [38:41<1:29:11,  1.84s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1800/4709 [38:43<1:30:20,  1.86s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1801/4709 [38:45<1:30:56,  1.88s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1802/4709 [38:47<1:31:08,  1.88s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1803/4709 [38:49<1:30:07,  1.86s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1804/4709 [38:51<1:30:51,  1.88s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1805/4709 [38:52<1:25:03,  1.76s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1806/4709 [38:54<1:27:23,  1.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1807/4709 [38:56<1:28:09,  1.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1808/4709 [38:57<1:26:35,  1.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1809/4709 [38:59<1:27:29,  1.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1810/4709 [39:01<1:28:12,  1.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1811/4709 [39:03<1:28:33,  1.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1812/4709 [39:05<1:29:15,  1.85s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1813/4709 [39:07<1:30:01,  1.87s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1814/4709 [39:09<1:31:07,  1.89s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1815/4709 [39:11<1:29:09,  1.85s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1816/4709 [39:12<1:30:35,  1.88s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1817/4709 [39:14<1:31:27,  1.90s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1818/4709 [39:16<1:28:56,  1.85s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1819/4709 [39:18<1:29:57,  1.87s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1820/4709 [39:20<1:28:41,  1.84s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1821/4709 [39:22<1:28:29,  1.84s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1822/4709 [39:24<1:29:20,  1.86s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1823/4709 [39:25<1:30:10,  1.87s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1824/4709 [39:27<1:30:23,  1.88s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1825/4709 [39:29<1:26:50,  1.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1826/4709 [39:31<1:29:03,  1.85s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1827/4709 [39:33<1:27:19,  1.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1828/4709 [39:35<1:29:26,  1.86s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1829/4709 [39:36<1:27:37,  1.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1830/4709 [39:38<1:24:36,  1.76s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1831/4709 [39:40<1:27:22,  1.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1832/4709 [39:42<1:27:40,  1.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1833/4709 [39:44<1:25:46,  1.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1834/4709 [39:46<1:28:36,  1.85s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1835/4709 [39:48<1:30:51,  1.90s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1836/4709 [39:49<1:31:24,  1.91s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1837/4709 [39:51<1:31:44,  1.92s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1838/4709 [39:53<1:32:28,  1.93s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1839/4709 [39:55<1:30:44,  1.90s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1840/4709 [39:57<1:32:18,  1.93s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1841/4709 [39:59<1:33:18,  1.95s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1842/4709 [40:01<1:29:00,  1.86s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1843/4709 [40:03<1:27:01,  1.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1844/4709 [40:05<1:28:33,  1.85s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1845/4709 [40:06<1:29:56,  1.88s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1846/4709 [40:08<1:31:09,  1.91s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1847/4709 [40:10<1:31:43,  1.92s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1848/4709 [40:12<1:32:23,  1.94s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1849/4709 [40:14<1:28:49,  1.86s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  54%|█████▍    | 2559/4709 [42:34<13:30,  2.65it/s]
# File cannot open
#  66%|██████▌   | 3115/4709 [46:09<10:31,  2.53it/s]
# File cannot open
#  68%|██████▊   | 3199/4709 [46:43<10:17,  2.44it/s]
# File cannot open
#  69%|██████▊   | 3226/4709 [46:54<11:35,  2.13it/s]
# File cannot open
#  69%|██████▊   | 3237/4709 [46:59<10:38,  2.31it/s]
# File cannot open
#  69%|██████▉   | 3242/4709 [47:00<09:14,  2.64it/s]
# File cannot open
#  69%|██████▉   | 3259/4709 [47:07<07:17,  3.31it/s]
# File cannot open
#  70%|██████▉   | 3283/4709 [47:16<08:29,  2.80it/s]
# File cannot open
#  70%|███████   | 3309/4709 [47:26<08:20,  2.80it/s]
# File cannot open
#  71%|███████   | 3325/4709 [47:32<09:55,  2.33it/s]
# File cannot open
#  71%|███████   | 3340/4709 [47:37<08:28,  2.69it/s]
# File cannot open
#  74%|███████▍  | 3493/4709 [48:36<07:42,  2.63it/s]
# File cannot open
#  76%|███████▋  | 3594/4709 [49:16<06:36,  2.81it/s]
# File cannot open
#  77%|███████▋  | 3607/4709 [49:21<06:26,  2.85it/s]
# File cannot open
#  78%|███████▊  | 3684/4709 [49:51<06:47,  2.51it/s]
# File cannot open
#  78%|███████▊  | 3695/4709 [49:55<05:01,  3.37it/s]
# File cannot open
#  80%|███████▉  | 3759/4709 [50:21<07:40,  2.06it/s]
# File cannot open
#  82%|████████▏ | 3843/4709 [50:59<05:32,  2.61it/s]
# File cannot open
#  82%|████████▏ | 3849/4709 [51:01<06:11,  2.31it/s]
# File cannot open
#  82%|████████▏ | 3852/4709 [51:02<04:49,  2.96it/s]
# File cannot open
#  85%|████████▌ | 4007/4709 [52:14<04:59,  2.35it/s]
# File cannot open
#  86%|████████▌ | 4031/4709 [52:23<03:59,  2.83it/s]
# File cannot open
#  86%|████████▌ | 4053/4709 [52:32<04:47,  2.28it/s]
# File cannot open
#  87%|████████▋ | 4081/4709 [52:44<05:16,  1.99it/s]
# File cannot open
#  88%|████████▊ | 4129/4709 [53:03<03:56,  2.45it/s]
# File cannot open
#  88%|████████▊ | 4143/4709 [53:08<04:15,  2.21it/s]
# File cannot open
#  88%|████████▊ | 4153/4709 [53:12<04:11,  2.21it/s]
# File cannot open
#  91%|█████████ | 4288/4709 [54:07<02:57,  2.37it/s]
# File cannot open
#  92%|█████████▏| 4324/4709 [54:22<02:33,  2.50it/s]
# File cannot open
#  97%|█████████▋| 4580/4709 [56:11<00:52,  2.45it/s]
# File cannot open
#  98%|█████████▊| 4603/4709 [56:19<00:22,  4.64it/s]
# File cannot open
#  99%|█████████▉| 4676/4709 [56:51<00:14,  2.36it/s]
# File cannot open
# 100%|█████████▉| 4698/4709 [57:00<00:04,  2.64it/s]
# File cannot open
# 100%|██████████| 4709/4709 [57:04<00:00,  1.38it/s]

# %%
isnone = lambda x: x is not None
label  = lambda x: 1 if  x == 'COVID-19' or x == 'positive_mild'   or  x == 'positive_moderate'  or  x == 'positive_asymp'  else 0
cast_x = list(map(isnone,features))
data_y = list(map(label,datamerge['STATUS']))

data_x = [features[i] for i in range(len(features)) if cast_x[i] == True]
data_xx = [imgpaths[i] for i in range(len(imgpaths)) if cast_x[i] == True]
data_xp = [diagnoses[i]for i in range(len(diagnoses))if cast_x[i] == True]
data_y = [data_y[i] for i in range(len(features)) if cast_x[i] == True]

# %%
assert len(data_x) == len(data_xx) == len(data_xp), "Data lengths do not match"

indices = np.arange(len(data_x))
NUM_shuf= 5
DATA    = {i:{} for i in range(NUM_shuf)}

for i in range(NUM_shuf):
  np.random.shuffle(indices)

  DATA[i]['MFCCS'] = np.array([data_x[i] for i in indices])
  DATA[i]['MEL']   = [data_xx[i] for i in indices]
  DATA[i]['EXTRA'] = np.array([data_xp[i] for i in indices])
  DATA[i]['LABELS']= np.array([data_y[i] for i in indices])

# %%
print(len(DATA[0]['MFCCS']))
# Out:
# 4630

# %%
import pickle

# Save extracted features
# Note: mel specs not saved
pickle.dump( DATA, open( "loaded_data.pickle", "wb" ) )

# %%
class CustomDataset(tf.keras.utils.Sequence):
  def __init__(self,imgfiles,labels,batch_size,target_size=(224,224),shuffle=False,scale=255,n_classes=1,n_channels=3):
    self.batch_size = batch_size
    self.dim        = target_size
    self.labels     = labels
    self.imgfiles   = imgfiles
    self.n_classes  = n_classes
    self.shuffle    = shuffle
    self.n_channels = n_channels
    self.scale      = scale

    self.c          = 0
    self.on_epoch_end()

  def __len__(self):
    # returns the number of batches
    return int(np.floor(len(self.imgfiles) / self.batch_size))

  def __getitem__(self, index):
    # returns one batch
    indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

    # Generate data
    X, y = self.__data_generation(indexes)
    return X, y

  def on_epoch_end(self):
    self.indexes = np.arange(len(self.imgfiles))
    if self.shuffle == True:
      np.random.shuffle(self.indexes)
  
  def __data_generation(self, list_IDs_temp):
    X = np.empty((self.batch_size, *self.dim, self.n_channels))
    y = np.empty((self.batch_size), dtype=int)

    # Generate data
    for i, ID in enumerate(list_IDs_temp):
        # Store sample
        img   = cv2.imread(self.imgfiles[ID])
        img   = cv2.resize(img,self.dim,interpolation = cv2.INTER_CUBIC)
        X[i,] = img / self.scale

        # Store class
        y[i] = self.labels[ID]

        self.c +=1
    return X, y #keras.utils.to_categorical(y, num_classes=self.n_classes)


class CustomPipeline(tf.keras.utils.Sequence):
  def __init__(self,data_x,data_y,batch_size=32,shuffle=False,n_classes=1):
    self.features   = data_x
    self.labels     = data_y
    self.batch_size = 32
    self.shuffle    = shuffle
    self.n_features = self.features.shape[1]
    self.n_classes  = 1
    self.on_epoch_end()

  def __len__(self):
    return int(np.floor(len(self.features) / self.batch_size))

  def __getitem__(self,index):
    indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
    X, y = self.__data_generation(indexes)
    return X, y

  def on_epoch_end(self):
    self.indexes = np.arange(len(self.features))
    if self.shuffle == True:
      np.random.shuffle(self.indexes)

  def __data_generation(self,indexes):
    X = np.empty((self.batch_size, self.n_features))
    y = np.empty((self.batch_size), dtype=int)

    for i, ID in enumerate(indexes):
      X[i,] = self.features[ID]
      y[i,] = self.labels[ID]
    return X, y

class MultipleInputGenerator(tf.keras.utils.Sequence):
  """Wrapper of two generatos for the combined input model"""

  def __init__(self, X1, X2, Y, batch_size,target_size=(224,224)):
      self.genX1 = CustomPipeline(X1, Y, batch_size=batch_size,shuffle=False)
      self.genX2 = CustomDataset (X2, Y, batch_size=batch_size,shuffle=False,target_size=target_size)

  def __len__(self):
      return self.genX1.__len__()

  def __getitem__(self, index):
      X1_batch, Y_batch = self.genX1.__getitem__(index)
      X2_batch, Y_batch = self.genX2.__getitem__(index)
      X_batch = [X1_batch, X2_batch]
      return X_batch, Y_batch

class TripleInputGenerator(tf.keras.utils.Sequence):
  """Wrapper of two generatos for the combined input model"""

  def __init__(self, X1, X2, X3, Y, batch_size,target_size=(224,224)):
      self.genX1 = CustomPipeline(X1, Y, batch_size=batch_size,shuffle=False)
      self.genX2 = CustomDataset (X2, Y, batch_size=batch_size,shuffle=False,target_size=target_size)
      self.genX3 = CustomPipeline(X3, Y, batch_size=batch_size,shuffle=False)
  def __len__(self):
      return self.genX1.__len__()

  def __getitem__(self, index):
      X1_batch, Y_batch = self.genX1.__getitem__(index)
      X2_batch, Y_batch = self.genX2.__getitem__(index)
      X3_batch, Y_batch = self.genX3.__getitem__(index)

      X_batch = [X1_batch,X1_batch,X2_batch, X3_batch]
      return X_batch, Y_batch

# %%
from sklearn.metrics import roc_auc_score
from keras.callbacks import Callback
class Evaluation(keras.callbacks.Callback):
  
  def __init__(self, val_data_gen, val_labels, test_data_gen, test_labels):
    super(Callback, self).__init__()
    self.test_data = test_data_gen
    self.val_labels = val_labels
    self.val_data = val_data_gen
    self.test_labels = test_labels

  def on_epoch_end(self, epoch, logs=None):
    y_preds = self.model.predict_generator(self.val_data)
    print(' | val_auc:', roc_auc_score(self.val_labels[:len(y_preds)], y_preds))

    y_preds = self.model.predict_generator(self.test_data)
    print(' | test_auc:', roc_auc_score(self.test_labels[:len(y_preds)], y_preds))

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

# %%
def build_model():
  '''Function to build ensemble model'''
  # First Model
  inp1   = Input(shape=13)
  lay1   = Dense(units=256,activation='relu',kernel_initializer='GlorotUniform')(inp1)
  lay2   = BatchNormalization()(lay1)
  lay3   = Dropout(0.5)(lay2)
  lay4   = Dense(units=256,activation='relu',kernel_initializer='GlorotUniform')(lay3)
  lay5   = BatchNormalization()(lay4)
  lay6   = Dropout(0.5)(lay5)

  #first +1 model
  inp11   = Input(shape=13)
  lay11   = Dense(units=64,activation='relu',kernel_initializer='GlorotUniform')(inp1)
  lay21   = BatchNormalization()(lay1)
  lay31   = Dropout(0.5)(lay2)
  lay41   = Dense(units=64,activation='relu',kernel_initializer='GlorotUniform')(lay3)
  lay51   = BatchNormalization()(lay4)
  lay61   = Dropout(0.5)(lay5)

  # first merge input models
  merge1 = concatenate([lay6,lay61])

# resnet
  inp2   = ResNet50(weights='imagenet', include_top=False)
  x = inp2.output

#first branch 
  x11 =   GlobalAveragePooling2D()(x)
  x21   = BatchNormalization()(x11)
  x31   = Dropout(0.5)(x21)

#second branch
  x12 =   GlobalAveragePooling2D()(x)
  x22   = BatchNormalization()(x12)
  x32   = Dropout(0.5)(x22)

#merge resnet 
  mergeXX = concatenate([x31,x32])
  x13   = BatchNormalization()(mergeXX)
  x23   = Dropout(0.5)(x13)


  # Third model
  inp3   = Input(shape=2)
  lay31  = Dense(units=5,activation='relu',kernel_initializer='GlorotUniform')(inp3)
  lay32  = BatchNormalization()(lay31)
  lay33  = Dropout(0.5)(lay32)
  lay34  = Dense(units=64,activation='relu',kernel_initializer='GlorotUniform')(lay33)
  lay35  = BatchNormalization()(lay34)
  lay36  = Dropout(0.5)(lay35)

 # second merge input models
  merge2 = concatenate([merge1,lay36])

  # merge input models
  merge3 = concatenate([x23, merge2])

  # interpretation model
  hidden1 = Dense(256, activation='relu')(merge3)
  hidden2  = BatchNormalization()(hidden1)
  hidden3  = Dropout(0.5)(hidden2)
  output  = Dense(1, activation='sigmoid')(hidden3)
  MERGM   = Model(inputs=[inp1,inp11 ,inp2.input,inp3], outputs=output)
  
  for layer in inp2.layers:
    layer.trainable = False


  return MERGM

# %%
# Create directory to save models
import matplotlib.pyplot as plt

rt_sv_dir = '/content/models'
# !rm -r {rt_sv_dir}
os.mkdir(rt_sv_dir)

# Run each split
for RUN in range(NUM_shuf):
  MERGM = build_model()

  #optimizer = keras.optimizers.Adam(lr=0.01)

  MERGM.compile(
      optimizer = 'Adam',
      loss = 'BinaryCrossentropy',
      metrics=['AUC'])
  

  tfeatures = DATA[RUN]['MFCCS'][:int(0.8*len(data_x))]
  textra    = DATA[RUN]['EXTRA'][:int(0.8*len(data_x))]
  timgs     = DATA[RUN]['MEL'][:int(0.8*len(data_x))]
  labels    = DATA[RUN]['LABELS'][:int(0.8*len(data_y))]

  test_features= DATA[RUN]['MFCCS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_extra   = DATA[RUN]['EXTRA'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_imgs    = DATA[RUN]['MEL'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_labels  = DATA[RUN]['LABELS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
                                        
  val_features= DATA[RUN]['MFCCS'][ int(0.9*len(data_x)) :]
  val_extra   = DATA[RUN]['EXTRA'][ int(0.9*len(data_x)) :]
  val_imgs    = DATA[RUN]['MEL'][ int(0.9*len(data_x)) :]
  val_labels  = DATA[RUN]['LABELS'][ int(0.9*len(data_x)) :]


  imgs_em      = TripleInputGenerator(tfeatures,timgs,textra,labels,batch_size=32,target_size=(224,224))
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=32,target_size=(224,224))
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=32,target_size=(224,224))


  evaluator = Evaluation(VAL, val_labels, TEST, test_labels)
  checkpointer = keras.callbacks.ModelCheckpoint(filepath=os.path.join(os.path.join(rt_sv_dir, str(RUN)),
                "{epoch:03d}--{val_loss:.3f}--{loss:.3f}.hdf5"), save_best_only=True)
  os.mkdir(os.path.join(rt_sv_dir, str(RUN)))
  history =  MERGM.fit_generator(
                  imgs_em,
                  epochs=50,
                  validation_data=VAL, 
                  verbose=2, 
                  callbacks=[evaluator, checkpointer])
  print(history.history.keys())
  plt.plot(history.history['auc'])
  plt.plot(history.history['val_auc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.savefig('accuracy.png')

  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.savefig('loss.png')

  plt.show()

  MERGM_Record1 = MERGM.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = MERGM.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = MERGM.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.savefig('ConfusionMatrix.png')
  plt.show()
# Out:
# rm: cannot remove '/content/models': No such file or directory
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 2s 0us/step
# 94781440/94765736 [==============================] - 2s 0us/step
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.664118677865732
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.6985153256704981
# 115/115 - 43s - loss: 0.8552 - auc: 0.6608 - val_loss: 0.6900 - val_auc: 0.6642 - 43s/epoch - 372ms/step
# Epoch 2/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7535601345499225
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7564854725415069
# 115/115 - 22s - loss: 0.6963 - auc: 0.6984 - val_loss: 0.5971 - val_auc: 0.7535 - 22s/epoch - 193ms/step
# Epoch 3/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7825246238443411
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8034003831417625
# 115/115 - 22s - loss: 0.6290 - auc: 0.7295 - val_loss: 0.5658 - val_auc: 0.7823 - 22s/epoch - 194ms/step
# Epoch 4/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7948315104638749
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8075111749680715
# 115/115 - 22s - loss: 0.6024 - auc: 0.7455 - val_loss: 0.5572 - val_auc: 0.7950 - 22s/epoch - 188ms/step
# Epoch 5/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8215803573226983
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8262691570881227
# 115/115 - 21s - loss: 0.5785 - auc: 0.7648 - val_loss: 0.5257 - val_auc: 0.8216 - 21s/epoch - 186ms/step
# Epoch 6/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8335448264749129
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.834331098339719
# 115/115 - 22s - loss: 0.5666 - auc: 0.7713 - val_loss: 0.5094 - val_auc: 0.8336 - 22s/epoch - 190ms/step
# Epoch 7/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8273108143493061
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8288633461047255
# 115/115 - 22s - loss: 0.5689 - auc: 0.7738 - val_loss: 0.5145 - val_auc: 0.8268 - 22s/epoch - 191ms/step
# Epoch 8/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8287308397284832
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8307790549169859
# 115/115 - 22s - loss: 0.5507 - auc: 0.7839 - val_loss: 0.5051 - val_auc: 0.8288 - 22s/epoch - 191ms/step
# Epoch 9/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8332930489254134
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8415948275862069
# 115/115 - 22s - loss: 0.5461 - auc: 0.7897 - val_loss: 0.5020 - val_auc: 0.8333 - 22s/epoch - 194ms/step
# Epoch 10/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8368179346184059
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8508540868454662
# 115/115 - 22s - loss: 0.5402 - auc: 0.7967 - val_loss: 0.5107 - val_auc: 0.8364 - 22s/epoch - 191ms/step
# Epoch 11/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8397586963965596
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8538074712643678
# 115/115 - 23s - loss: 0.5296 - auc: 0.8075 - val_loss: 0.4971 - val_auc: 0.8398 - 23s/epoch - 199ms/step
# Epoch 12/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8405039579430781
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8565014367816093
# 115/115 - 23s - loss: 0.5298 - auc: 0.8079 - val_loss: 0.4912 - val_auc: 0.8406 - 23s/epoch - 196ms/step
# Epoch 13/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8406248111668378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8542265325670497
# 115/115 - 22s - loss: 0.5189 - auc: 0.8187 - val_loss: 0.4904 - val_auc: 0.8406 - 22s/epoch - 192ms/step
# Epoch 14/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8410276552460371
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8623084291187739
# 115/115 - 22s - loss: 0.5228 - auc: 0.8134 - val_loss: 0.4890 - val_auc: 0.8408 - 22s/epoch - 189ms/step
# Epoch 15/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8474933027171833
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8657407407407407
# 115/115 - 22s - loss: 0.5132 - auc: 0.8199 - val_loss: 0.4829 - val_auc: 0.8475 - 22s/epoch - 193ms/step
# Epoch 16/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8481579954478619
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.860632183908046
# 115/115 - 22s - loss: 0.5085 - auc: 0.8233 - val_loss: 0.4779 - val_auc: 0.8482 - 22s/epoch - 191ms/step
# Epoch 17/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8420750498519548
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8658006066411238
# 115/115 - 22s - loss: 0.4984 - auc: 0.8312 - val_loss: 0.4879 - val_auc: 0.8420 - 22s/epoch - 189ms/step
# Epoch 18/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8417729167925554
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8656210089399744
# 115/115 - 21s - loss: 0.5175 - auc: 0.8162 - val_loss: 0.4882 - val_auc: 0.8420 - 21s/epoch - 187ms/step
# Epoch 19/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8464257659073054
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.865301724137931
# 115/115 - 22s - loss: 0.5008 - auc: 0.8304 - val_loss: 0.4831 - val_auc: 0.8467 - 22s/epoch - 187ms/step
# Epoch 20/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8512598948576954
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8700510855683269
# 115/115 - 21s - loss: 0.5050 - auc: 0.8283 - val_loss: 0.4822 - val_auc: 0.8511 - 21s/epoch - 185ms/step
# Epoch 21/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8551070558140471
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8663593550446999
# 115/115 - 21s - loss: 0.5082 - auc: 0.8233 - val_loss: 0.4795 - val_auc: 0.8553 - 21s/epoch - 179ms/step
# Epoch 22/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.856637863315004
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8741818326947637
# 115/115 - 21s - loss: 0.4936 - auc: 0.8367 - val_loss: 0.4714 - val_auc: 0.8566 - 21s/epoch - 183ms/step
# Epoch 23/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8554192599754264
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8623283844189016
# 115/115 - 22s - loss: 0.4946 - auc: 0.8354 - val_loss: 0.4824 - val_auc: 0.8553 - 22s/epoch - 187ms/step
# Epoch 24/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8524684270952927
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8740022349936143
# 115/115 - 22s - loss: 0.4890 - auc: 0.8412 - val_loss: 0.4839 - val_auc: 0.8527 - 22s/epoch - 190ms/step
# Epoch 25/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.852750417950732
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8661997126436781
# 115/115 - 22s - loss: 0.4969 - auc: 0.8339 - val_loss: 0.4898 - val_auc: 0.8532 - 22s/epoch - 190ms/step
# Epoch 26/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.85375752814873
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.87360312899106
# 115/115 - 22s - loss: 0.4861 - auc: 0.8402 - val_loss: 0.4976 - val_auc: 0.8538 - 22s/epoch - 188ms/step
# Epoch 27/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8523475738715329
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8733636653895276
# 115/115 - 21s - loss: 0.4926 - auc: 0.8358 - val_loss: 0.4835 - val_auc: 0.8523 - 21s/epoch - 186ms/step
# Epoch 28/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8511994682458155
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8637252554278416
# 115/115 - 22s - loss: 0.4890 - auc: 0.8403 - val_loss: 0.4913 - val_auc: 0.8516 - 22s/epoch - 193ms/step
# Epoch 29/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8604447398634358
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8659203384418902
# 115/115 - 21s - loss: 0.4830 - auc: 0.8449 - val_loss: 0.4817 - val_auc: 0.8603 - 21s/epoch - 186ms/step
# Epoch 30/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8549257759784076
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8637252554278416
# 115/115 - 21s - loss: 0.4863 - auc: 0.8421 - val_loss: 0.4871 - val_auc: 0.8544 - 21s/epoch - 183ms/step
# Epoch 31/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8529115555824117
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8669181034482759
# 115/115 - 21s - loss: 0.4939 - auc: 0.8337 - val_loss: 0.4817 - val_auc: 0.8530 - 21s/epoch - 185ms/step
# Epoch 32/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8579672487763611
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8738425925925926
# 115/115 - 21s - loss: 0.4804 - auc: 0.8443 - val_loss: 0.4805 - val_auc: 0.8580 - 21s/epoch - 186ms/step
# Epoch 33/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8600620379881967
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8742217432950191
# 115/115 - 22s - loss: 0.4777 - auc: 0.8468 - val_loss: 0.4710 - val_auc: 0.8604 - 22s/epoch - 189ms/step
# Epoch 34/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8558926017684856
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8650223499361429
# 115/115 - 22s - loss: 0.4810 - auc: 0.8483 - val_loss: 0.4866 - val_auc: 0.8560 - 22s/epoch - 187ms/step
# Epoch 35/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8535963905170504
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.874022190293742
# 115/115 - 21s - loss: 0.4782 - auc: 0.8473 - val_loss: 0.4848 - val_auc: 0.8536 - 21s/epoch - 186ms/step
# Epoch 36/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8457006465647471
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8628871328224776
# 115/115 - 22s - loss: 0.4749 - auc: 0.8510 - val_loss: 0.4967 - val_auc: 0.8456 - 22s/epoch - 189ms/step
# Epoch 37/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8540596612081294
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8696120689655172
# 115/115 - 22s - loss: 0.4640 - auc: 0.8549 - val_loss: 0.4796 - val_auc: 0.8542 - 22s/epoch - 188ms/step
# Epoch 38/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8667492497029025
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8831218071519795
# 115/115 - 23s - loss: 0.4610 - auc: 0.8594 - val_loss: 0.4640 - val_auc: 0.8666 - 23s/epoch - 197ms/step
# Epoch 39/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.858027675388241
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8738825031928481
# 115/115 - 22s - loss: 0.4657 - auc: 0.8571 - val_loss: 0.4720 - val_auc: 0.8585 - 22s/epoch - 193ms/step
# Epoch 40/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.861330996837674
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8828424329501916
# 115/115 - 22s - loss: 0.4587 - auc: 0.8606 - val_loss: 0.4715 - val_auc: 0.8617 - 22s/epoch - 190ms/step
# Epoch 41/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8498700827844583
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8761574074074073
# 115/115 - 22s - loss: 0.4503 - auc: 0.8675 - val_loss: 0.4872 - val_auc: 0.8502 - 22s/epoch - 189ms/step
# Epoch 42/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.857121276210043
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8820442209450831
# 115/115 - 21s - loss: 0.4606 - auc: 0.8592 - val_loss: 0.4779 - val_auc: 0.8573 - 21s/epoch - 185ms/step
# Epoch 43/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8630229419703104
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8799090038314177
# 115/115 - 21s - loss: 0.4501 - auc: 0.8665 - val_loss: 0.4686 - val_auc: 0.8633 - 21s/epoch - 181ms/step
# Epoch 44/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8560940238080852
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8700510855683268
# 115/115 - 21s - loss: 0.4419 - auc: 0.8708 - val_loss: 0.4905 - val_auc: 0.8559 - 21s/epoch - 185ms/step
# Epoch 45/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8521864362398535
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8718670178799489
# 115/115 - 22s - loss: 0.4525 - auc: 0.8670 - val_loss: 0.4896 - val_auc: 0.8523 - 22s/epoch - 188ms/step
# Epoch 46/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8588333635466392
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8805276181353767
# 115/115 - 21s - loss: 0.4531 - auc: 0.8659 - val_loss: 0.4817 - val_auc: 0.8588 - 21s/epoch - 183ms/step
# Epoch 47/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8612907124297541
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8872924648786719
# 115/115 - 21s - loss: 0.4443 - auc: 0.8714 - val_loss: 0.4772 - val_auc: 0.8616 - 21s/epoch - 184ms/step
# Epoch 48/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8645940338791871
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8806074393358877
# 115/115 - 21s - loss: 0.4529 - auc: 0.8648 - val_loss: 0.4757 - val_auc: 0.8647 - 21s/epoch - 186ms/step
# Epoch 49/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8613813523475738
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8734035759897828
# 115/115 - 21s - loss: 0.4500 - auc: 0.8697 - val_loss: 0.4815 - val_auc: 0.8614 - 21s/epoch - 186ms/step
# Epoch 50/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8602231756198764
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8718869731800766
# 115/115 - 22s - loss: 0.4406 - auc: 0.8716 - val_loss: 0.4804 - val_auc: 0.8601 - 22s/epoch - 189ms/step
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.46352437138557434 , AUC = 0.8718371391296387
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:82: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8602231756198764
# test 0.8718869731800766
#
# -----------------------------------------------------------------
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7507588465532392
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7235791826309068
# 115/115 - 30s - loss: 0.8822 - auc: 0.6799 - val_loss: 0.6108 - val_auc: 0.7507 - 30s/epoch - 263ms/step
# Epoch 2/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8041377106797668
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8058947956577267
# 115/115 - 23s - loss: 0.6880 - auc: 0.7356 - val_loss: 0.6085 - val_auc: 0.8041 - 23s/epoch - 196ms/step
# Epoch 3/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7908179567058071
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8069324712643678
# 115/115 - 22s - loss: 0.6347 - auc: 0.7443 - val_loss: 0.5805 - val_auc: 0.7907 - 22s/epoch - 196ms/step
# Epoch 4/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8388050163751097
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8423331736909323
# 115/115 - 22s - loss: 0.5776 - auc: 0.7742 - val_loss: 0.5023 - val_auc: 0.8390 - 22s/epoch - 193ms/step
# Epoch 5/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8510863487499001
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8498563218390804
# 115/115 - 22s - loss: 0.5602 - auc: 0.7869 - val_loss: 0.4894 - val_auc: 0.8509 - 22s/epoch - 193ms/step
# Epoch 6/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8523044971643101
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8426125478927203
# 115/115 - 22s - loss: 0.5440 - auc: 0.7968 - val_loss: 0.4825 - val_auc: 0.8522 - 22s/epoch - 191ms/step
# Epoch 7/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8580557552520169
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8596344189016604
# 115/115 - 22s - loss: 0.5452 - auc: 0.7969 - val_loss: 0.4753 - val_auc: 0.8579 - 22s/epoch - 189ms/step
# Epoch 8/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8522845275181724
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8456856641123882
# 115/115 - 22s - loss: 0.5198 - auc: 0.8134 - val_loss: 0.4762 - val_auc: 0.8529 - 22s/epoch - 189ms/step
# Epoch 9/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8511861969805895
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8557630906768837
# 115/115 - 22s - loss: 0.5255 - auc: 0.8097 - val_loss: 0.4779 - val_auc: 0.8513 - 22s/epoch - 188ms/step
# Epoch 10/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.844935697739436
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8498762771392081
# 115/115 - 21s - loss: 0.5234 - auc: 0.8127 - val_loss: 0.4819 - val_auc: 0.8447 - 21s/epoch - 187ms/step
# Epoch 11/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8531032830098251
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8481800766283525
# 115/115 - 21s - loss: 0.5091 - auc: 0.8241 - val_loss: 0.4818 - val_auc: 0.8535 - 21s/epoch - 183ms/step
# Epoch 12/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8449956066778497
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8525103767560664
# 115/115 - 21s - loss: 0.5100 - auc: 0.8236 - val_loss: 0.4836 - val_auc: 0.8452 - 21s/epoch - 185ms/step
# Epoch 13/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8524642543334133
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8611310664112388
# 115/115 - 22s - loss: 0.4981 - auc: 0.8293 - val_loss: 0.4766 - val_auc: 0.8522 - 22s/epoch - 189ms/step
# Epoch 14/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8593737518971164
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8606122286079183
# 115/115 - 22s - loss: 0.5101 - auc: 0.8216 - val_loss: 0.4682 - val_auc: 0.8593 - 22s/epoch - 191ms/step
# Epoch 15/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8649253135234444
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8578783524904214
# 115/115 - 23s - loss: 0.5064 - auc: 0.8237 - val_loss: 0.4590 - val_auc: 0.8648 - 23s/epoch - 196ms/step
# Epoch 16/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.850966530873073
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.861330619412516
# 115/115 - 22s - loss: 0.4961 - auc: 0.8337 - val_loss: 0.4822 - val_auc: 0.8513 - 22s/epoch - 189ms/step
# Epoch 17/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8591141464973242
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8616499042145592
# 115/115 - 22s - loss: 0.5015 - auc: 0.8317 - val_loss: 0.4818 - val_auc: 0.8593 - 22s/epoch - 193ms/step
# Epoch 18/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8699976036424635
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8623682950191571
# 115/115 - 23s - loss: 0.4913 - auc: 0.8381 - val_loss: 0.4490 - val_auc: 0.8700 - 23s/epoch - 196ms/step
# Epoch 19/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8602923556194584
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8684746168582376
# 115/115 - 22s - loss: 0.4901 - auc: 0.8372 - val_loss: 0.4652 - val_auc: 0.8604 - 22s/epoch - 195ms/step
# Epoch 20/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8693585749660515
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8660001596424011
# 115/115 - 22s - loss: 0.4961 - auc: 0.8348 - val_loss: 0.4518 - val_auc: 0.8696 - 22s/epoch - 194ms/step
# Epoch 21/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8742111989775542
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8620490102171137
# 115/115 - 22s - loss: 0.4936 - auc: 0.8341 - val_loss: 0.4449 - val_auc: 0.8740 - 22s/epoch - 195ms/step
# Epoch 22/50
# ...
#   app.launch_new_instance()
#  | test_auc: 0.8593194820837098
# 115/115 - 22s - loss: 0.4868 - auc: 0.8386 - val_loss: 0.4933 - val_auc: 0.8361 - 22s/epoch - 188ms/step
# Epoch 28/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8362369685251261
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8570310147545919
# 115/115 - 22s - loss: 0.4748 - auc: 0.8487 - val_loss: 0.4897 - val_auc: 0.8364 - 22s/epoch - 192ms/step
# Epoch 29/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8307154105288338
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8569908662049583
# 115/115 - 22s - loss: 0.4696 - auc: 0.8513 - val_loss: 0.4991 - val_auc: 0.8308 - 22s/epoch - 191ms/step
# Epoch 30/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8402136862877988
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8660845126969787
# 115/115 - 22s - loss: 0.4751 - auc: 0.8488 - val_loss: 0.4818 - val_auc: 0.8403 - 22s/epoch - 189ms/step
# Epoch 31/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8410508900273088
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8619692863595303
# 115/115 - 22s - loss: 0.4677 - auc: 0.8535 - val_loss: 0.4892 - val_auc: 0.8412 - 22s/epoch - 190ms/step
# Epoch 32/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8434728008451771
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8668874836896517
# 115/115 - 22s - loss: 0.4731 - auc: 0.8507 - val_loss: 0.4843 - val_auc: 0.8436 - 22s/epoch - 194ms/step
# Epoch 33/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8403233201108298
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8612466124661247
# 115/115 - 23s - loss: 0.4680 - auc: 0.8540 - val_loss: 0.4914 - val_auc: 0.8402 - 23s/epoch - 196ms/step
# Epoch 34/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8392867821476269
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8633945598715247
# 115/115 - 22s - loss: 0.4744 - auc: 0.8494 - val_loss: 0.4881 - val_auc: 0.8393 - 22s/epoch - 193ms/step
# Epoch 35/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8396256503279048
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8629127772759209
# 115/115 - 22s - loss: 0.4589 - auc: 0.8602 - val_loss: 0.4935 - val_auc: 0.8394 - 22s/epoch - 194ms/step
# Epoch 36/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8404030538003069
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.863916491016762
# 115/115 - 22s - loss: 0.4608 - auc: 0.8603 - val_loss: 0.4865 - val_auc: 0.8403 - 22s/epoch - 193ms/step
# Epoch 37/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8427352642175135
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8661848840710629
# 115/115 - 23s - loss: 0.4615 - auc: 0.8586 - val_loss: 0.4849 - val_auc: 0.8428 - 23s/epoch - 198ms/step
# Epoch 38/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8486156238164532
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8636354511693265
# 115/115 - 22s - loss: 0.4672 - auc: 0.8542 - val_loss: 0.4772 - val_auc: 0.8487 - 22s/epoch - 193ms/step
# Epoch 39/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8454163095261825
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8697982535380909
# 115/115 - 22s - loss: 0.4605 - auc: 0.8602 - val_loss: 0.4814 - val_auc: 0.8455 - 22s/epoch - 194ms/step
# Epoch 40/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.853000976737696
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8715246411723376
# 115/115 - 22s - loss: 0.4662 - auc: 0.8547 - val_loss: 0.4803 - val_auc: 0.8527 - 22s/epoch - 190ms/step
# Epoch 41/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8539777144337912
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8732510288065843
# 115/115 - 22s - loss: 0.4396 - auc: 0.8716 - val_loss: 0.4785 - val_auc: 0.8541 - 22s/epoch - 193ms/step
# Epoch 42/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8338449578408117
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8610057211683227
# 115/115 - 22s - loss: 0.4456 - auc: 0.8682 - val_loss: 0.4926 - val_auc: 0.8337 - 22s/epoch - 192ms/step
# Epoch 43/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8441704706281021
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8673291177356217
# 115/115 - 22s - loss: 0.4449 - auc: 0.8680 - val_loss: 0.4897 - val_auc: 0.8444 - 22s/epoch - 189ms/step
# Epoch 44/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8286822014471664
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8607447555957042
# 115/115 - 22s - loss: 0.4521 - auc: 0.8641 - val_loss: 0.5009 - val_auc: 0.8285 - 22s/epoch - 190ms/step
# Epoch 45/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8419777941674806
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8618488407106294
# 115/115 - 22s - loss: 0.4426 - auc: 0.8725 - val_loss: 0.4911 - val_auc: 0.8419 - 22s/epoch - 191ms/step
# Epoch 46/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8397851177068592
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8567499749071564
# 115/115 - 23s - loss: 0.4542 - auc: 0.8616 - val_loss: 0.4898 - val_auc: 0.8398 - 23s/epoch - 196ms/step
# Epoch 47/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.841379791496402
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8602629730001004
# 115/115 - 22s - loss: 0.4431 - auc: 0.8711 - val_loss: 0.5061 - val_auc: 0.8413 - 22s/epoch - 192ms/step
# Epoch 48/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8454262762373672
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8691157281943189
# 115/115 - 22s - loss: 0.4272 - auc: 0.8798 - val_loss: 0.4946 - val_auc: 0.8455 - 22s/epoch - 191ms/step
# Epoch 49/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8404229872226763
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8649402790324199
# 115/115 - 22s - loss: 0.4398 - auc: 0.8712 - val_loss: 0.4934 - val_auc: 0.8402 - 22s/epoch - 193ms/step
# Epoch 50/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8376721749357147
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8615878751380106
# 115/115 - 23s - loss: 0.4371 - auc: 0.8756 - val_loss: 0.4943 - val_auc: 0.8376 - 23s/epoch - 199ms/step
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.46402111649513245 , AUC = 0.8618890643119812
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:82: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8376721749357147
# test 0.8615878751380106
#
# -----------------------------------------------------------------

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {
          0: '/content/models/0/038--0.464--0.461.hdf5',
          1: '/content/models/1/044--0.436--0.443.hdf5',
          2: '/content/models/2/024--0.484--0.469.hdf5',
          3: '/content/models/3/021--0.471--0.475.hdf5',
          4: '/content/models/4/025--0.474--0.480.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(5):
  print(iii)

  test_features= DATA[RUN]['MFCCS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_extra   = DATA[RUN]['EXTRA'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_imgs    = DATA[RUN]['MEL'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_labels  = DATA[RUN]['LABELS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=32,target_size=(224,224))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)
  

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 448
# acc:  0.8370535714285714
# 1
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Num_samples: 448
# acc:  0.8415178571428571
# 2
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Num_samples: 448
# acc:  0.8035714285714286
# 3
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Num_samples: 448
# acc:  0.8147321428571429
# 4
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Num_samples: 448
# acc:  0.7834821428571429
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:54: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {
          0: '/content/models/0/038--0.464--0.461.hdf5',
          1: '/content/models/1/044--0.436--0.443.hdf5',
          2: '/content/models/2/024--0.484--0.469.hdf5',
          3: '/content/models/3/021--0.471--0.475.hdf5',
          4: '/content/models/4/025--0.474--0.480.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(5):
  print(iii)

  test_features= DATA[RUN]['MFCCS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_extra   = DATA[RUN]['EXTRA'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_imgs    = DATA[RUN]['MEL'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_labels  = DATA[RUN]['LABELS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=32,target_size=(224,224))

                                     
  val_features= DATA[RUN]['MFCCS'][ int(0.9*len(data_x)) :]
  val_extra   = DATA[RUN]['EXTRA'][ int(0.9*len(data_x)) :]
  val_imgs    = DATA[RUN]['MEL'][ int(0.9*len(data_x)) :]
  val_labels  = DATA[RUN]['LABELS'][ int(0.9*len(data_x)) :]
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=32,target_size=(224,224))


  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)
    

  MERGM_Record1 = model.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = model.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = model.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.savefig('ConfusionMatrix.png')
  plt.show()

  

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 448
# acc:  0.8370535714285714
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.38210466504096985 , AUC = 0.9171735048294067
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.9039707377359618
# test 0.917113319281341
#
# -----------------------------------------------------------------
# 1
# Num_samples: 448
# acc:  0.8415178571428571
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.37165018916130066 , AUC = 0.9337950944900513
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.9096517631112087
# test 0.933694670280036
#
# -----------------------------------------------------------------
# 2
# Num_samples: 448
# acc:  0.8035714285714286
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.41414207220077515 , AUC = 0.9016461372375488
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8866286602746827
# test 0.9016561276723878
#
# -----------------------------------------------------------------
# 3
# Num_samples: 448
# acc:  0.8147321428571429
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.4233630299568176 , AUC = 0.9011843204498291
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8841569159008911
# test 0.9010338251530664
#
# -----------------------------------------------------------------
# 4
# Num_samples: 448
# acc:  0.7834821428571429
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.46235230565071106 , AUC = 0.8655123114585876
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.848306655769729
# test 0.8656830272006424
#
# -----------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:88: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {
          #0: '/content/models/0/038--0.464--0.461.hdf5',
          0: '/content/models/1/044--0.436--0.443.hdf5'
          #2: '/content/models/2/024--0.484--0.469.hdf5',
          #3: '/content/models/3/021--0.471--0.475.hdf5',
          #4: '/content/models/4/025--0.474--0.480.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(1):
  print(iii)

  test_features= DATA[RUN]['MFCCS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_extra   = DATA[RUN]['EXTRA'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_imgs    = DATA[RUN]['MEL'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_labels  = DATA[RUN]['LABELS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=32,target_size=(224,224))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)
  
  y_test  = test_labels
  y_preds_test = model.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.savefig('ConfusionMatrix.png')
  plt.show()

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 448
# acc:  0.8415178571428571
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# test 0.933694670280036
#
# -----------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ### 80 epoch

# %%
# Create directory to save models
import matplotlib.pyplot as plt

rt_sv_dir = '/content/models/80'
# !rm -r {rt_sv_dir}
os.mkdir(rt_sv_dir)

# Run each split
for RUN in range(NUM_shuf):
  MERGM = build_model()

  #optimizer = keras.optimizers.Adam(lr=0.01)

  MERGM.compile(
      optimizer = 'Adam',
      loss = 'BinaryCrossentropy',
      metrics=['AUC'])
  
  tfeatures = DATA[RUN]['MFCCS'][:int(0.8*len(data_x))]
  textra    = DATA[RUN]['EXTRA'][:int(0.8*len(data_x))]
  timgs     = DATA[RUN]['MEL'][:int(0.8*len(data_x))]
  labels    = DATA[RUN]['LABELS'][:int(0.8*len(data_y))]

  test_features= DATA[RUN]['MFCCS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_extra   = DATA[RUN]['EXTRA'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_imgs    = DATA[RUN]['MEL'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_labels  = DATA[RUN]['LABELS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
                                        
  val_features= DATA[RUN]['MFCCS'][ int(0.9*len(data_x)) :]
  val_extra   = DATA[RUN]['EXTRA'][ int(0.9*len(data_x)) :]
  val_imgs    = DATA[RUN]['MEL'][ int(0.9*len(data_x)) :]
  val_labels  = DATA[RUN]['LABELS'][ int(0.9*len(data_x)) :]

  imgs_em      = TripleInputGenerator(tfeatures,timgs,textra,labels,batch_size=32,target_size=(224,224))
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=32,target_size=(224,224))
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=32,target_size=(224,224))


  evaluator = Evaluation(VAL, val_labels, TEST, test_labels)
  checkpointer = keras.callbacks.ModelCheckpoint(filepath=os.path.join(os.path.join(rt_sv_dir, str(RUN)),
                "{epoch:03d}--{val_loss:.3f}--{loss:.3f}.hdf5"), save_best_only=True)
  os.mkdir(os.path.join(rt_sv_dir, str(RUN)))
  history =  MERGM.fit_generator(
                  imgs_em,
                  epochs=80,
                  validation_data=VAL, 
                  verbose=2, 
                  callbacks=[evaluator, checkpointer])
  print(history.history.keys())
  plt.plot(history.history['auc'])
  plt.plot(history.history['val_auc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.savefig('accuracy.png')

  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.savefig('loss.png')

  plt.show()

  MERGM_Record1 = MERGM.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = MERGM.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = MERGM.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.savefig('ConfusionMatrix.png')
  plt.show()
# Out:
# rm: cannot remove '/content/models/80': No such file or directory
# Epoch 1/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.6915221463532539
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.6890964240102171
# 115/115 - 33s - loss: 0.8533 - auc: 0.6853 - val_loss: 0.8167 - val_auc: 0.6918 - 33s/epoch - 284ms/step
# Epoch 2/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7747598042177775
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7866778416347382
# 115/115 - 23s - loss: 0.6666 - auc: 0.7462 - val_loss: 0.5890 - val_auc: 0.7750 - 23s/epoch - 199ms/step
# Epoch 3/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8074606723467681
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8420338441890166
# 115/115 - 23s - loss: 0.6153 - auc: 0.7602 - val_loss: 0.5326 - val_auc: 0.8071 - 23s/epoch - 199ms/step
# Epoch 4/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8307752734304187
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8548651021711366
# 115/115 - 23s - loss: 0.5908 - auc: 0.7681 - val_loss: 0.5198 - val_auc: 0.8306 - 23s/epoch - 204ms/step
# Epoch 5/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8330815557838338
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8577187100893997
# 115/115 - 23s - loss: 0.5629 - auc: 0.7842 - val_loss: 0.5101 - val_auc: 0.8328 - 23s/epoch - 200ms/step
# Epoch 6/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8404233891272384
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8600933908045977
# 115/115 - 23s - loss: 0.5429 - auc: 0.7997 - val_loss: 0.4971 - val_auc: 0.8399 - 23s/epoch - 198ms/step
# Epoch 7/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8483191330795417
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8645833333333333
# 115/115 - 23s - loss: 0.5366 - auc: 0.8042 - val_loss: 0.4838 - val_auc: 0.8480 - 23s/epoch - 198ms/step
# Epoch 8/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8389932926460812
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8580379948914431
# 115/115 - 24s - loss: 0.5247 - auc: 0.8120 - val_loss: 0.4860 - val_auc: 0.8391 - 24s/epoch - 206ms/step
# Epoch 9/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8475537293290631
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.865241858237548
# 115/115 - 23s - loss: 0.5198 - auc: 0.8165 - val_loss: 0.4822 - val_auc: 0.8476 - 23s/epoch - 197ms/step
# Epoch 10/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8463955526013656
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.865162037037037
# 115/115 - 23s - loss: 0.5134 - auc: 0.8207 - val_loss: 0.4846 - val_auc: 0.8461 - 23s/epoch - 198ms/step
# Epoch 11/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8418232723024552
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8737029054916986
# 115/115 - 22s - loss: 0.5162 - auc: 0.8201 - val_loss: 0.4840 - val_auc: 0.8419 - 22s/epoch - 191ms/step
# Epoch 12/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8513606058774952
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8732838441890166
# 115/115 - 23s - loss: 0.5089 - auc: 0.8257 - val_loss: 0.4715 - val_auc: 0.8511 - 23s/epoch - 203ms/step
# Epoch 13/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8421153342598748
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8661797573435503
# 115/115 - 22s - loss: 0.5006 - auc: 0.8327 - val_loss: 0.4910 - val_auc: 0.8418 - 22s/epoch - 194ms/step
# Epoch 14/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8443611900014101
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8688737228607919
# 115/115 - 22s - loss: 0.4992 - auc: 0.8314 - val_loss: 0.4796 - val_auc: 0.8443 - 22s/epoch - 191ms/step
# Epoch 15/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8442101234717103
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8704501915708812
# 115/115 - 22s - loss: 0.4970 - auc: 0.8324 - val_loss: 0.4913 - val_auc: 0.8445 - 22s/epoch - 191ms/step
# Epoch 16/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8441094124519105
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8717073754789272
# 115/115 - 22s - loss: 0.5016 - auc: 0.8311 - val_loss: 0.4789 - val_auc: 0.8442 - 22s/epoch - 195ms/step
# Epoch 17/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8499305093963381
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8706696998722862
# 115/115 - 23s - loss: 0.4864 - auc: 0.8418 - val_loss: 0.4727 - val_auc: 0.8500 - 23s/epoch - 198ms/step
# Epoch 18/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8493161721755594
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8709291187739463
# 115/115 - 22s - loss: 0.4847 - auc: 0.8426 - val_loss: 0.4768 - val_auc: 0.8490 - 22s/epoch - 195ms/step
# Epoch 19/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8386710173827221
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8582575031928479
# 115/115 - 22s - loss: 0.4927 - auc: 0.8378 - val_loss: 0.4855 - val_auc: 0.8387 - 22s/epoch - 191ms/step
# Epoch 20/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.84433097669547
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.869073275862069
# 115/115 - 22s - loss: 0.4846 - auc: 0.8428 - val_loss: 0.4804 - val_auc: 0.8448 - 22s/epoch - 192ms/step
# Epoch 21/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8513404636735351
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8674169859514687
# 115/115 - 23s - loss: 0.4760 - auc: 0.8504 - val_loss: 0.4783 - val_auc: 0.8510 - 23s/epoch - 196ms/step
# Epoch 22/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8520857252200535
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.870949074074074
# 115/115 - 22s - loss: 0.4823 - auc: 0.8454 - val_loss: 0.4811 - val_auc: 0.8523 - 22s/epoch - 193ms/step
# Epoch 23/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8463049126835459
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8689934546615581
# 115/115 - 22s - loss: 0.4745 - auc: 0.8512 - val_loss: 0.4835 - val_auc: 0.8461 - 22s/epoch - 194ms/step
# Epoch 24/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8513404636735351
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8743614303959132
# 115/115 - 22s - loss: 0.4754 - auc: 0.8488 - val_loss: 0.4765 - val_auc: 0.8513 - 22s/epoch - 195ms/step
# Epoch 25/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8558523173605654
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8708492975734354
# 115/115 - 23s - loss: 0.4729 - auc: 0.8510 - val_loss: 0.4681 - val_auc: 0.8556 - 23s/epoch - 200ms/step
# Epoch 26/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8605655930871956
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8775941890166029
# 115/115 - 23s - loss: 0.4641 - auc: 0.8572 - val_loss: 0.4639 - val_auc: 0.8605 - 23s/epoch - 199ms/step
# Epoch 27/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8595584828891977
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8721064814814815
# 115/115 - 23s - loss: 0.4786 - auc: 0.8496 - val_loss: 0.4614 - val_auc: 0.8600 - 23s/epoch - 197ms/step
# Epoch 28/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8631236529901103
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8807471264367815
# 115/115 - 22s - loss: 0.4681 - auc: 0.8557 - val_loss: 0.4638 - val_auc: 0.8631 - 22s/epoch - 191ms/step
# Epoch 29/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8573226982496425
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8788713282247766
# 115/115 - 22s - loss: 0.4648 - auc: 0.8580 - val_loss: 0.4690 - val_auc: 0.8575 - 22s/epoch - 189ms/step
# Epoch 30/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8583499506516004
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.875279374201788
# 115/115 - 22s - loss: 0.4687 - auc: 0.8568 - val_loss: 0.4703 - val_auc: 0.8583 - 22s/epoch - 195ms/step
# Epoch 31/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.866447116643503
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8746607598978289
# 115/115 - 22s - loss: 0.4641 - auc: 0.8601 - val_loss: 0.4655 - val_auc: 0.8663 - 22s/epoch - 195ms/step
# Epoch 32/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.862217253811912
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8765166028097062
# 115/115 - 22s - loss: 0.4569 - auc: 0.8632 - val_loss: 0.4657 - val_auc: 0.8622 - 22s/epoch - 189ms/step
# Epoch 33/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8607065885149153
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8817848020434227
# 115/115 - 22s - loss: 0.4593 - auc: 0.8622 - val_loss: 0.4674 - val_auc: 0.8605 - 22s/epoch - 191ms/step
# Epoch 34/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8555098998932461
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8713282247765007
# 115/115 - 22s - loss: 0.4497 - auc: 0.8675 - val_loss: 0.4817 - val_auc: 0.8556 - 22s/epoch - 194ms/step
# Epoch 35/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8562954458476847
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8678560025542784
# 115/115 - 22s - loss: 0.4441 - auc: 0.8703 - val_loss: 0.4828 - val_auc: 0.8564 - 22s/epoch - 191ms/step
# Epoch 36/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8536568171289303
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8739822796934865
# 115/115 - 22s - loss: 0.4607 - auc: 0.8593 - val_loss: 0.4815 - val_auc: 0.8536 - 22s/epoch - 190ms/step
# Epoch 37/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8614719922653937
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8837005108556832
# 115/115 - 22s - loss: 0.4523 - auc: 0.8655 - val_loss: 0.4721 - val_auc: 0.8615 - 22s/epoch - 192ms/step
# Epoch 38/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8591556388099986
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8746408045977011
# 115/115 - 22s - loss: 0.4340 - auc: 0.8772 - val_loss: 0.4770 - val_auc: 0.8593 - 22s/epoch - 191ms/step
# Epoch 39/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8630833685821903
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8771352171136654
# 115/115 - 22s - loss: 0.4452 - auc: 0.8704 - val_loss: 0.4748 - val_auc: 0.8631 - 22s/epoch - 194ms/step
# Epoch 40/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8602131045178962
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8726851851851852
# 115/115 - 22s - loss: 0.4333 - auc: 0.8793 - val_loss: 0.4719 - val_auc: 0.8604 - 22s/epoch - 190ms/step
# Epoch 41/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8590549277901988
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8651819923371646
# 115/115 - 21s - loss: 0.4344 - auc: 0.8790 - val_loss: 0.4731 - val_auc: 0.8591 - 21s/epoch - 187ms/step
# Epoch 42/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8597196205208775
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8751795977011494
# 115/115 - 22s - loss: 0.4321 - auc: 0.8795 - val_loss: 0.4753 - val_auc: 0.8597 - 22s/epoch - 189ms/step
# Epoch 43/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8652385844059057
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8720466155810984
# 115/115 - 22s - loss: 0.4424 - auc: 0.8718 - val_loss: 0.4656 - val_auc: 0.8656 - 22s/epoch - 195ms/step
# Epoch 44/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8624791024633915
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8702905491698595
# 115/115 - 22s - loss: 0.4384 - auc: 0.8747 - val_loss: 0.4687 - val_auc: 0.8624 - 22s/epoch - 193ms/step
# Epoch 45/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8730336173384093
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8821040868454662
# 115/115 - 23s - loss: 0.4360 - auc: 0.8775 - val_loss: 0.4559 - val_auc: 0.8729 - 23s/epoch - 197ms/step
# Epoch 46/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8643724696356274
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8729446040868454
# 115/115 - 22s - loss: 0.4315 - auc: 0.8787 - val_loss: 0.4661 - val_auc: 0.8646 - 22s/epoch - 190ms/step
# Epoch 47/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8538380969645699
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.85448595146871
# 115/115 - 22s - loss: 0.4309 - auc: 0.8784 - val_loss: 0.4795 - val_auc: 0.8539 - 22s/epoch - 188ms/step
# Epoch 48/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8562753036437247
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8743215197956578
# 115/115 - 22s - loss: 0.4311 - auc: 0.8787 - val_loss: 0.4774 - val_auc: 0.8562 - 22s/epoch - 190ms/step
# Epoch 49/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8567990009466836
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8753591954022989
# 115/115 - 22s - loss: 0.4250 - auc: 0.8830 - val_loss: 0.4815 - val_auc: 0.8571 - 22s/epoch - 189ms/step
# Epoch 50/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8677160754929805
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8773946360153256
# 115/115 - 22s - loss: 0.4269 - auc: 0.8833 - val_loss: 0.4631 - val_auc: 0.8675 - 22s/epoch - 190ms/step
# Epoch 51/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.859498056277318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8666586845466157
# 115/115 - 22s - loss: 0.4260 - auc: 0.8824 - val_loss: 0.4786 - val_auc: 0.8592 - 22s/epoch - 192ms/step
# Epoch 52/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8538582391685298
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8602530332056194
# 115/115 - 22s - loss: 0.4229 - auc: 0.8856 - val_loss: 0.4927 - val_auc: 0.8541 - 22s/epoch - 191ms/step
# Epoch 53/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8609180816564947
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8702705938697318
# 115/115 - 22s - loss: 0.4249 - auc: 0.8837 - val_loss: 0.4883 - val_auc: 0.8605 - 22s/epoch - 188ms/step
# Epoch 54/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.860867726146595
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8682351532567051
# 115/115 - 22s - loss: 0.4283 - auc: 0.8815 - val_loss: 0.4727 - val_auc: 0.8609 - 22s/epoch - 193ms/step
# Epoch 55/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8678772131246602
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8805276181353767
# 115/115 - 22s - loss: 0.4249 - auc: 0.8833 - val_loss: 0.4683 - val_auc: 0.8681 - 22s/epoch - 192ms/step
# Epoch 56/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.863748061312869
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8767361111111112
# 115/115 - 22s - loss: 0.4126 - auc: 0.8898 - val_loss: 0.4719 - val_auc: 0.8636 - 22s/epoch - 189ms/step
# Epoch 57/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8613914234495539
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8715477330779055
# 115/115 - 22s - loss: 0.4237 - auc: 0.8838 - val_loss: 0.4712 - val_auc: 0.8616 - 22s/epoch - 190ms/step
# Epoch 58/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8629423731544705
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.879809227330779
# 115/115 - 22s - loss: 0.4031 - auc: 0.8959 - val_loss: 0.4853 - val_auc: 0.8625 - 22s/epoch - 191ms/step
# Epoch 59/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8592563498297984
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8681353767560663
# 115/115 - 22s - loss: 0.4210 - auc: 0.8843 - val_loss: 0.4785 - val_auc: 0.8595 - 22s/epoch - 192ms/step
# Epoch 60/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8720265071404112
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8690932311621966
# 115/115 - 22s - loss: 0.3976 - auc: 0.8989 - val_loss: 0.4642 - val_auc: 0.8717 - 22s/epoch - 188ms/step
# Epoch 61/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8664672588474631
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8633660600255426
# 115/115 - 22s - loss: 0.4105 - auc: 0.8918 - val_loss: 0.4732 - val_auc: 0.8662 - 22s/epoch - 187ms/step
# Epoch 62/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8717848006928919
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8801085568326947
# 115/115 - 22s - loss: 0.4027 - auc: 0.8962 - val_loss: 0.4752 - val_auc: 0.8720 - 22s/epoch - 189ms/step
# Epoch 63/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8611497170020345
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8718869731800767
# 115/115 - 22s - loss: 0.4010 - auc: 0.8983 - val_loss: 0.4830 - val_auc: 0.8608 - 22s/epoch - 190ms/step
# Epoch 64/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8661449835841039
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8648427522349936
# 115/115 - 22s - loss: 0.4029 - auc: 0.8961 - val_loss: 0.4675 - val_auc: 0.8664 - 22s/epoch - 190ms/step
# Epoch 65/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8619251918544928
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8690333652618136
# 115/115 - 22s - loss: 0.3954 - auc: 0.9007 - val_loss: 0.4791 - val_auc: 0.8615 - 22s/epoch - 188ms/step
# Epoch 66/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8637480613128689
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8625279374201787
# 115/115 - 22s - loss: 0.3954 - auc: 0.9021 - val_loss: 0.4775 - val_auc: 0.8637 - 22s/epoch - 187ms/step
# Epoch 67/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8577255423288417
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8736430395913154
# 115/115 - 21s - loss: 0.3935 - auc: 0.9012 - val_loss: 0.4910 - val_auc: 0.8574 - 21s/epoch - 182ms/step
# Epoch 68/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8513606058774951
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8651221264367817
# 115/115 - 22s - loss: 0.3959 - auc: 0.8990 - val_loss: 0.5111 - val_auc: 0.8512 - 22s/epoch - 190ms/step
# Epoch 69/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8553084778536466
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8610911558109833
# 115/115 - 22s - loss: 0.3891 - auc: 0.9049 - val_loss: 0.5568 - val_auc: 0.8552 - 22s/epoch - 190ms/step
# Epoch 70/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.859921042560477
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8549848339719028
# 115/115 - 22s - loss: 0.3999 - auc: 0.8978 - val_loss: 0.4972 - val_auc: 0.8601 - 22s/epoch - 190ms/step
# Epoch 71/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8586520837109998
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8600933908045977
# 115/115 - 21s - loss: 0.3938 - auc: 0.9014 - val_loss: 0.5123 - val_auc: 0.8585 - 21s/epoch - 187ms/step
# Epoch 72/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8619755473643925
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8651021711366538
# 115/115 - 21s - loss: 0.3955 - auc: 0.8993 - val_loss: 0.4875 - val_auc: 0.8620 - 21s/epoch - 185ms/step
# Epoch 73/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8638890567405886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8672573435504469
# 115/115 - 22s - loss: 0.3940 - auc: 0.9029 - val_loss: 0.4766 - val_auc: 0.8636 - 22s/epoch - 191ms/step
# ...
#   app.launch_new_instance()
#  | test_auc: 0.8676904546823246
# 115/115 - 21s - loss: 0.4484 - auc: 0.8660 - val_loss: 0.4969 - val_auc: 0.8468 - 21s/epoch - 183ms/step
# Epoch 58/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8468714493591404
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8578339857472648
# 115/115 - 22s - loss: 0.4410 - auc: 0.8723 - val_loss: 0.4798 - val_auc: 0.8472 - 22s/epoch - 190ms/step
# Epoch 59/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8482667889249904
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8560473752885678
# 115/115 - 22s - loss: 0.4456 - auc: 0.8686 - val_loss: 0.4830 - val_auc: 0.8483 - 22s/epoch - 188ms/step
# Epoch 60/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8459844120637073
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8611663153668574
# 115/115 - 22s - loss: 0.4489 - auc: 0.8667 - val_loss: 0.4830 - val_auc: 0.8459 - 22s/epoch - 188ms/step
# Epoch 61/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8504494986744273
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8607648298705209
# 115/115 - 21s - loss: 0.4476 - auc: 0.8683 - val_loss: 0.4741 - val_auc: 0.8503 - 21s/epoch - 184ms/step
# Epoch 62/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8541571152351146
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8592191107096255
# 115/115 - 21s - loss: 0.4421 - auc: 0.8695 - val_loss: 0.4724 - val_auc: 0.8543 - 21s/epoch - 185ms/step
# Epoch 63/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8461538461538461
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8607046070460704
# 115/115 - 21s - loss: 0.4478 - auc: 0.8679 - val_loss: 0.4811 - val_auc: 0.8462 - 21s/epoch - 185ms/step
# Epoch 64/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8558115892917655
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8568704205560576
# 115/115 - 22s - loss: 0.4415 - auc: 0.8721 - val_loss: 0.4701 - val_auc: 0.8558 - 22s/epoch - 192ms/step
# Epoch 65/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8501803974724421
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.855565592692964
# 115/115 - 22s - loss: 0.4284 - auc: 0.8793 - val_loss: 0.4738 - val_auc: 0.8503 - 22s/epoch - 189ms/step
# Epoch 66/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8368549046185738
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8450868212385827
# 115/115 - 22s - loss: 0.4346 - auc: 0.8759 - val_loss: 0.4911 - val_auc: 0.8367 - 22s/epoch - 191ms/step
# Epoch 67/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8428149979069905
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8565291578841714
# 115/115 - 21s - loss: 0.4391 - auc: 0.8722 - val_loss: 0.4944 - val_auc: 0.8427 - 21s/epoch - 187ms/step
# Epoch 68/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8575358303267087
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8663454782695975
# 115/115 - 23s - loss: 0.4357 - auc: 0.8777 - val_loss: 0.4657 - val_auc: 0.8574 - 23s/epoch - 199ms/step
# Epoch 69/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.845147208324197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8523537087222725
# 115/115 - 22s - loss: 0.4396 - auc: 0.8738 - val_loss: 0.4823 - val_auc: 0.8452 - 22s/epoch - 191ms/step
# Epoch 70/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8454462096597365
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8571715346783096
# 115/115 - 22s - loss: 0.4301 - auc: 0.8807 - val_loss: 0.4790 - val_auc: 0.8453 - 22s/epoch - 188ms/step
# Epoch 71/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8519544720633085
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8637157482685938
# 115/115 - 22s - loss: 0.4232 - auc: 0.8822 - val_loss: 0.4753 - val_auc: 0.8519 - 22s/epoch - 187ms/step
# Epoch 72/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8405027209121535
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8622503262069657
# 115/115 - 22s - loss: 0.4286 - auc: 0.8795 - val_loss: 0.4882 - val_auc: 0.8404 - 22s/epoch - 189ms/step
# Epoch 73/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8449678075228735
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8576131687242798
# 115/115 - 22s - loss: 0.4218 - auc: 0.8848 - val_loss: 0.4856 - val_auc: 0.8450 - 22s/epoch - 188ms/step
# Epoch 74/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8510275679231367
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8555053698685136
# 115/115 - 22s - loss: 0.4245 - auc: 0.8818 - val_loss: 0.4844 - val_auc: 0.8511 - 22s/epoch - 188ms/step
# Epoch 75/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8240377140351227
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8444243701696277
# 115/115 - 22s - loss: 0.4115 - auc: 0.8907 - val_loss: 0.5103 - val_auc: 0.8239 - 22s/epoch - 192ms/step
# Epoch 76/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8486255905276378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8603432700993677
# 115/115 - 22s - loss: 0.4240 - auc: 0.8841 - val_loss: 0.4837 - val_auc: 0.8488 - 22s/epoch - 190ms/step
# Epoch 77/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.84757908585325
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8618287664358125
# 115/115 - 22s - loss: 0.4329 - auc: 0.8768 - val_loss: 0.4791 - val_auc: 0.8477 - 22s/epoch - 189ms/step
# Epoch 78/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8459445452189687
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8588778480377396
# 115/115 - 23s - loss: 0.4087 - auc: 0.8926 - val_loss: 0.4836 - val_auc: 0.8457 - 23s/epoch - 197ms/step
# Epoch 79/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8551936531983176
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8697380307136404
# 115/115 - 22s - loss: 0.4201 - auc: 0.8844 - val_loss: 0.4739 - val_auc: 0.8550 - 22s/epoch - 190ms/step
# Epoch 80/80
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8371937727988519
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8538392050587172
# 115/115 - 22s - loss: 0.4174 - auc: 0.8887 - val_loss: 0.5025 - val_auc: 0.8369 - 22s/epoch - 191ms/step
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:71: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.47693443298339844 , AUC = 0.8540701270103455
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:80: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8371937727988519
# test 0.8538392050587172
#
# -----------------------------------------------------------------

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {0: '/content/models/80/0/045--0.456--0.436.hdf5',
          1: '/content/models/80/1/078--0.419--0.383.hdf5',
          2: '/content/models/80/2/075--0.466--0.400.hdf5',
          3: '/content/models/80/3/016--0.571--0.557.hdf5',
          4: '/content/models/80/4/068--0.466--0.436.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(5):
  print(iii)


  test_features= DATA[RUN]['MFCCS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_extra   = DATA[RUN]['EXTRA'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_imgs    = DATA[RUN]['MEL'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_labels  = DATA[RUN]['LABELS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
                                        
                                        
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=32,target_size=(224,224))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)
  

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 448
# acc:  0.84375
# 1
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Num_samples: 448
# acc:  0.890625
# 2
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Num_samples: 448
# acc:  0.8794642857142857
# 3
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Num_samples: 448
# acc:  0.75
# 4
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Num_samples: 448
# acc:  0.78125
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:56: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {0: '/content/models/80/0/045--0.456--0.436.hdf5',
          1: '/content/models/80/1/078--0.419--0.383.hdf5',
          2: '/content/models/80/2/075--0.466--0.400.hdf5',
          3: '/content/models/80/3/016--0.571--0.557.hdf5',
          4: '/content/models/80/4/068--0.466--0.436.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(5):
  print(iii)

  test_features= DATA[RUN]['MFCCS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_extra   = DATA[RUN]['EXTRA'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_imgs    = DATA[RUN]['MEL'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_labels  = DATA[RUN]['LABELS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=32,target_size=(224,224))

                                     
  val_features= DATA[RUN]['MFCCS'][ int(0.9*len(data_x)) :]
  val_extra   = DATA[RUN]['EXTRA'][ int(0.9*len(data_x)) :]
  val_imgs    = DATA[RUN]['MEL'][ int(0.9*len(data_x)) :]
  val_labels  = DATA[RUN]['LABELS'][ int(0.9*len(data_x)) :]
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=32,target_size=(224,224))


  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)
    

  MERGM_Record1 = model.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = model.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = model.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.savefig('ConfusionMatrix.png')
  plt.show()

  

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 448
# acc:  0.84375
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.3507608473300934 , AUC = 0.938883900642395
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.9159706580022724
# test 0.9387333132590585
#
# -----------------------------------------------------------------
# 1
# Num_samples: 448
# acc:  0.890625
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.3040556013584137 , AUC = 0.9574325084686279
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.9504255785675844
# test 0.957442537388337
#
# -----------------------------------------------------------------
# 2
# Num_samples: 448
# acc:  0.8794642857142857
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.3281993269920349 , AUC = 0.9489410519599915
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.9311200590029302
# test 0.9488507477667371
#
# -----------------------------------------------------------------
# 3
# Num_samples: 448
# acc:  0.75
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.49827486276626587 , AUC = 0.8522934913635254
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8185261227500149
# test 0.8520325203252033
#
# -----------------------------------------------------------------
# 4
# Num_samples: 448
# acc:  0.78125
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.4562632441520691 , AUC = 0.8665963411331177
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8575358303267087
# test 0.8663454782695975
#
# -----------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:87: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {
    
    #0: '/content/models/80/0/045--0.456--0.436.hdf5',
          0: '/content/models/80/1/078--0.419--0.383.hdf5'
    #      2: '/content/models/80/2/075--0.466--0.400.hdf5',
    #      3: '/content/models/80/3/016--0.571--0.557.hdf5',
    #      4: '/content/models/80/4/068--0.466--0.436.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(1):
  print(iii)


  test_features= DATA[RUN]['MFCCS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_extra   = DATA[RUN]['EXTRA'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_imgs    = DATA[RUN]['MEL'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_labels  = DATA[RUN]['LABELS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
                                        
                                        
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=32,target_size=(224,224))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)
  
  y_test  = test_labels
  y_preds_test = model.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.savefig('ConfusionMatrix.png')
  plt.show()

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 448
# acc:  0.890625
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# test 0.957442537388337
#
# -----------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:68: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {0: '/content/models/1/137--0.460--0.316.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(1):
  print(iii)


  test_features= DATA[RUN]['MFCCS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_extra   = DATA[RUN]['EXTRA'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_imgs    = DATA[RUN]['MEL'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_labels  = DATA[RUN]['LABELS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
                                        
                                        
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=32,target_size=(224,224))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()

# %% [markdown]
# ## 150 epoch

# %%
# Create directory to save models
import matplotlib.pyplot as plt

rt_sv_dir = '/content/models/150'
# !rm -r {rt_sv_dir}
os.mkdir(rt_sv_dir)

# Run each split
for RUN in range(NUM_shuf):
  MERGM = build_model()

  #optimizer = keras.optimizers.Adam(lr=0.01)

  MERGM.compile(
      optimizer = 'Adam',
      loss = 'BinaryCrossentropy',
      metrics=['AUC'])
  
  tfeatures = DATA[RUN]['MFCCS'][:int(0.8*len(data_x))]
  textra    = DATA[RUN]['EXTRA'][:int(0.8*len(data_x))]
  timgs     = DATA[RUN]['MEL'][:int(0.8*len(data_x))]
  labels    = DATA[RUN]['LABELS'][:int(0.8*len(data_y))]

  test_features= DATA[RUN]['MFCCS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_extra   = DATA[RUN]['EXTRA'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_imgs    = DATA[RUN]['MEL'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_labels  = DATA[RUN]['LABELS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
                                        
  val_features= DATA[RUN]['MFCCS'][ int(0.9*len(data_x)) :]
  val_extra   = DATA[RUN]['EXTRA'][ int(0.9*len(data_x)) :]
  val_imgs    = DATA[RUN]['MEL'][ int(0.9*len(data_x)) :]
  val_labels  = DATA[RUN]['LABELS'][ int(0.9*len(data_x)) :]

  imgs_em      = TripleInputGenerator(tfeatures,timgs,textra,labels,batch_size=32,target_size=(224,224))
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=32,target_size=(224,224))
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=32,target_size=(224,224))


  evaluator = Evaluation(VAL, val_labels, TEST, test_labels)
  checkpointer = keras.callbacks.ModelCheckpoint(filepath=os.path.join(os.path.join(rt_sv_dir, str(RUN)),
                "{epoch:03d}--{val_loss:.3f}--{loss:.3f}.hdf5"), save_best_only=True)
  os.mkdir(os.path.join(rt_sv_dir, str(RUN)))
  history =  MERGM.fit_generator(
                  imgs_em,
                  epochs=150,
                  validation_data=VAL, 
                  verbose=2, 
                  callbacks=[evaluator, checkpointer])
  print(history.history.keys())
  plt.plot(history.history['auc'])
  plt.plot(history.history['val_auc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.savefig('accuracy.png')

  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.savefig('loss.png')

  plt.show()

  MERGM_Record1 = MERGM.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = MERGM.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = MERGM.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.savefig('ConfusionMatrix.png')
  plt.show()
# Out:
# rm: cannot remove '/content/models/150': No such file or directory
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.6479646302898463
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.6300886015325671
# 115/115 - 31s - loss: 0.9037 - auc: 0.6834 - val_loss: 0.7410 - val_auc: 0.6471 - 31s/epoch - 273ms/step
# Epoch 2/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7946401595262554
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.826668263090677
# 115/115 - 23s - loss: 0.7206 - auc: 0.7145 - val_loss: 0.5721 - val_auc: 0.7948 - 23s/epoch - 199ms/step
# Epoch 3/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.812727858682297
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8437899106002554
# 115/115 - 23s - loss: 0.6042 - auc: 0.7656 - val_loss: 0.5350 - val_auc: 0.8123 - 23s/epoch - 202ms/step
# Epoch 4/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8246218301206518
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8463441890166028
# 115/115 - 23s - loss: 0.5863 - auc: 0.7685 - val_loss: 0.5082 - val_auc: 0.8251 - 23s/epoch - 198ms/step
# Epoch 5/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8390134348500413
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8532487228607919
# 115/115 - 23s - loss: 0.5561 - auc: 0.7891 - val_loss: 0.4983 - val_auc: 0.8390 - 23s/epoch - 199ms/step
# Epoch 6/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8415916369569159
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8628671775223499
# 115/115 - 23s - loss: 0.5581 - auc: 0.7836 - val_loss: 0.4917 - val_auc: 0.8415 - 23s/epoch - 199ms/step
# Epoch 7/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8350152073639898
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8529294380587484
# 115/115 - 23s - loss: 0.5481 - auc: 0.7933 - val_loss: 0.4956 - val_auc: 0.8349 - 23s/epoch - 201ms/step
# Epoch 8/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8345015811630109
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8570003192848019
# 115/115 - 24s - loss: 0.5295 - auc: 0.8094 - val_loss: 0.4893 - val_auc: 0.8345 - 24s/epoch - 207ms/step
# Epoch 9/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8352065583016094
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8584371008939975
# 115/115 - 22s - loss: 0.5202 - auc: 0.8158 - val_loss: 0.4974 - val_auc: 0.8349 - 22s/epoch - 193ms/step
# Epoch 10/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8431325155598524
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.859035759897829
# 115/115 - 23s - loss: 0.5296 - auc: 0.8083 - val_loss: 0.4851 - val_auc: 0.8430 - 23s/epoch - 202ms/step
# Epoch 11/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8408060910024774
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8626875798212006
# 115/115 - 23s - loss: 0.5209 - auc: 0.8164 - val_loss: 0.4878 - val_auc: 0.8409 - 23s/epoch - 198ms/step
# Epoch 12/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8394162789292403
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8650423052362708
# 115/115 - 23s - loss: 0.5152 - auc: 0.8181 - val_loss: 0.4936 - val_auc: 0.8396 - 23s/epoch - 200ms/step
# Epoch 13/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8449553850182286
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8636653895274585
# 115/115 - 23s - loss: 0.5059 - auc: 0.8257 - val_loss: 0.4862 - val_auc: 0.8453 - 23s/epoch - 197ms/step
# Epoch 14/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.84431083449151
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8711685823754789
# 115/115 - 23s - loss: 0.5055 - auc: 0.8255 - val_loss: 0.4880 - val_auc: 0.8443 - 23s/epoch - 197ms/step
# Epoch 15/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8543517231655486
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8694524265644955
# 115/115 - 23s - loss: 0.5013 - auc: 0.8289 - val_loss: 0.4779 - val_auc: 0.8544 - 23s/epoch - 204ms/step
# Epoch 16/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.859437629665438
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8650423052362707
# 115/115 - 23s - loss: 0.5055 - auc: 0.8265 - val_loss: 0.4693 - val_auc: 0.8596 - 23s/epoch - 204ms/step
# Epoch 17/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8508771929824561
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8610911558109835
# 115/115 - 23s - loss: 0.5074 - auc: 0.8236 - val_loss: 0.4753 - val_auc: 0.8514 - 23s/epoch - 197ms/step
# Epoch 18/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8565270811932242
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8673970306513409
# 115/115 - 23s - loss: 0.4975 - auc: 0.8335 - val_loss: 0.4775 - val_auc: 0.8566 - 23s/epoch - 197ms/step
# Epoch 19/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8536971015368502
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8678959131545338
# 115/115 - 22s - loss: 0.5005 - auc: 0.8301 - val_loss: 0.4777 - val_auc: 0.8535 - 22s/epoch - 195ms/step
# Epoch 20/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8496082341329788
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.873682950191571
# 115/115 - 22s - loss: 0.4991 - auc: 0.8299 - val_loss: 0.4820 - val_auc: 0.8496 - 22s/epoch - 193ms/step
# Epoch 21/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8510383306141359
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8744811621966795
# 115/115 - 22s - loss: 0.4865 - auc: 0.8403 - val_loss: 0.4792 - val_auc: 0.8507 - 22s/epoch - 193ms/step
# Epoch 22/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.852387858279453
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.868095466155811
# 115/115 - 22s - loss: 0.4961 - auc: 0.8345 - val_loss: 0.4873 - val_auc: 0.8525 - 22s/epoch - 193ms/step
# Epoch 23/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8503736378834572
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8606122286079183
# 115/115 - 23s - loss: 0.4832 - auc: 0.8445 - val_loss: 0.5058 - val_auc: 0.8505 - 23s/epoch - 198ms/step
# Epoch 24/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8451366648538684
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.859574553001277
# 115/115 - 22s - loss: 0.4807 - auc: 0.8464 - val_loss: 0.5034 - val_auc: 0.8452 - 22s/epoch - 194ms/step
# Epoch 25/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8582693818357605
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8721663473818647
# 115/115 - 22s - loss: 0.4891 - auc: 0.8378 - val_loss: 0.5129 - val_auc: 0.8581 - 22s/epoch - 193ms/step
# Epoch 26/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8530223377041916
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8581776819923372
# 115/115 - 22s - loss: 0.4866 - auc: 0.8407 - val_loss: 0.5337 - val_auc: 0.8531 - 22s/epoch - 188ms/step
# Epoch 27/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.855630753117006
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8675167624521073
# 115/115 - 22s - loss: 0.4753 - auc: 0.8493 - val_loss: 0.5380 - val_auc: 0.8556 - 22s/epoch - 191ms/step
# Epoch 28/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8513303925715552
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8649824393358876
# 115/115 - 22s - loss: 0.4784 - auc: 0.8472 - val_loss: 0.5081 - val_auc: 0.8514 - 22s/epoch - 194ms/step
# Epoch 29/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8507059842487965
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8606920498084291
# 115/115 - 22s - loss: 0.4711 - auc: 0.8529 - val_loss: 0.5336 - val_auc: 0.8505 - 22s/epoch - 194ms/step
# Epoch 30/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8560436682981852
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8635855683269476
# 115/115 - 22s - loss: 0.4776 - auc: 0.8492 - val_loss: 0.5188 - val_auc: 0.8565 - 22s/epoch - 194ms/step
# Epoch 31/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8544322919813886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8574193805874841
# 115/115 - 22s - loss: 0.4702 - auc: 0.8541 - val_loss: 0.5008 - val_auc: 0.8544 - 22s/epoch - 190ms/step
# Epoch 32/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8538783813724897
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8677961366538953
# 115/115 - 22s - loss: 0.4680 - auc: 0.8550 - val_loss: 0.5228 - val_auc: 0.8537 - 22s/epoch - 195ms/step
# Epoch 33/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8460732773380063
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8551045657726691
# 115/115 - 23s - loss: 0.4609 - auc: 0.8600 - val_loss: 0.5407 - val_auc: 0.8458 - 23s/epoch - 196ms/step
# Epoch 34/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8548854915704877
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8774944125159643
# 115/115 - 22s - loss: 0.4694 - auc: 0.8535 - val_loss: 0.5365 - val_auc: 0.8547 - 22s/epoch - 195ms/step
# Epoch 35/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8495276653171391
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8769755747126436
# 115/115 - 22s - loss: 0.4673 - auc: 0.8538 - val_loss: 0.4902 - val_auc: 0.8494 - 22s/epoch - 192ms/step
# Epoch 36/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8561141660120449
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8701109514687101
# 115/115 - 22s - loss: 0.4590 - auc: 0.8626 - val_loss: 0.4850 - val_auc: 0.8559 - 22s/epoch - 192ms/step
# Epoch 37/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8562148770318448
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8721264367816092
# 115/115 - 21s - loss: 0.4572 - auc: 0.8639 - val_loss: 0.4857 - val_auc: 0.8563 - 21s/epoch - 185ms/step
# Epoch 38/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8521260096279736
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8715477330779055
# 115/115 - 22s - loss: 0.4594 - auc: 0.8607 - val_loss: 0.4847 - val_auc: 0.8518 - 22s/epoch - 192ms/step
# Epoch 39/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8408262332064376
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8596344189016603
# 115/115 - 22s - loss: 0.4540 - auc: 0.8652 - val_loss: 0.5153 - val_auc: 0.8407 - 22s/epoch - 194ms/step
# Epoch 40/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8567587165387638
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8749600893997446
# 115/115 - 22s - loss: 0.4518 - auc: 0.8669 - val_loss: 0.4869 - val_auc: 0.8568 - 22s/epoch - 190ms/step
# Epoch 41/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8594779140733578
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8704901021711368
# 115/115 - 22s - loss: 0.4438 - auc: 0.8711 - val_loss: 0.4871 - val_auc: 0.8596 - 22s/epoch - 193ms/step
# Epoch 42/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8541603722279292
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8697118454661558
# 115/115 - 22s - loss: 0.4471 - auc: 0.8687 - val_loss: 0.5124 - val_auc: 0.8542 - 22s/epoch - 194ms/step
# Epoch 43/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8507160553507764
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8698116219667943
# 115/115 - 22s - loss: 0.4408 - auc: 0.8735 - val_loss: 0.5161 - val_auc: 0.8509 - 22s/epoch - 193ms/step
# Epoch 44/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.860847583942635
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8744412515964239
# 115/115 - 22s - loss: 0.4443 - auc: 0.8703 - val_loss: 0.4982 - val_auc: 0.8610 - 22s/epoch - 189ms/step
# Epoch 45/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8580578886941809
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8774145913154534
# 115/115 - 22s - loss: 0.4495 - auc: 0.8695 - val_loss: 0.5388 - val_auc: 0.8586 - 22s/epoch - 190ms/step
# Epoch 46/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8538683102705098
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8668183269476373
# 115/115 - 22s - loss: 0.4546 - auc: 0.8629 - val_loss: 0.5162 - val_auc: 0.8538 - 22s/epoch - 189ms/step
# Epoch 47/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8563458013575845
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8739822796934865
# 115/115 - 22s - loss: 0.4389 - auc: 0.8734 - val_loss: 0.5152 - val_auc: 0.8563 - 22s/epoch - 193ms/step
# Epoch 48/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8549761314883075
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.873323754789272
# 115/115 - 22s - loss: 0.4432 - auc: 0.8728 - val_loss: 0.5167 - val_auc: 0.8551 - 22s/epoch - 195ms/step
# Epoch 49/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.85848087497734
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8791307471264368
# 115/115 - 22s - loss: 0.4287 - auc: 0.8803 - val_loss: 0.5501 - val_auc: 0.8587 - 22s/epoch - 191ms/step
# Epoch 50/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8648659536326465
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8733037994891444
# 115/115 - 23s - loss: 0.4300 - auc: 0.8790 - val_loss: 0.5203 - val_auc: 0.8650 - 23s/epoch - 198ms/step
# Epoch 51/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8608878683505549
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8781928480204343
# 115/115 - 22s - loss: 0.4334 - auc: 0.8780 - val_loss: 0.5181 - val_auc: 0.8612 - 22s/epoch - 195ms/step
# Epoch 52/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8510081173081958
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8702905491698596
# 115/115 - 22s - loss: 0.4228 - auc: 0.8855 - val_loss: 0.5413 - val_auc: 0.8513 - 22s/epoch - 191ms/step
# Epoch 53/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.862328035933692
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8775542784163473
# 115/115 - 23s - loss: 0.4262 - auc: 0.8824 - val_loss: 0.5578 - val_auc: 0.8625 - 23s/epoch - 196ms/step
# Epoch 54/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8517735210586743
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8713880906768838
# 115/115 - 22s - loss: 0.4185 - auc: 0.8875 - val_loss: 0.5792 - val_auc: 0.8519 - 22s/epoch - 192ms/step
# Epoch 55/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8539690212903096
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.875139687100894
# 115/115 - 22s - loss: 0.4249 - auc: 0.8840 - val_loss: 0.5594 - val_auc: 0.8543 - 22s/epoch - 190ms/step
# Epoch 56/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8545732874091084
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8643837803320561
# 115/115 - 22s - loss: 0.4245 - auc: 0.8836 - val_loss: 0.5803 - val_auc: 0.8547 - 22s/epoch - 188ms/step
# Epoch 57/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8496988740507987
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8612308429118773
# 115/115 - 22s - loss: 0.4209 - auc: 0.8868 - val_loss: 0.5822 - val_auc: 0.8501 - 22s/epoch - 192ms/step
# Epoch 58/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8585413015892199
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8767959770114941
# 115/115 - 22s - loss: 0.4238 - auc: 0.8834 - val_loss: 0.5501 - val_auc: 0.8586 - 22s/epoch - 194ms/step
# Epoch 59/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8489133280963603
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8648427522349936
# 115/115 - 22s - loss: 0.4158 - auc: 0.8897 - val_loss: 0.5942 - val_auc: 0.8491 - 22s/epoch - 195ms/step
# Epoch 60/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8517130944467943
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8685344827586207
# 115/115 - 22s - loss: 0.4208 - auc: 0.8867 - val_loss: 0.6007 - val_auc: 0.8517 - 22s/epoch - 193ms/step
# Epoch 61/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8483292041815215
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8644835568326947
# 115/115 - 22s - loss: 0.4113 - auc: 0.8910 - val_loss: 0.6020 - val_auc: 0.8485 - 22s/epoch - 189ms/step
# Epoch 62/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8522267206477733
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8715477330779056
# 115/115 - 22s - loss: 0.4257 - auc: 0.8840 - val_loss: 0.6060 - val_auc: 0.8526 - 22s/epoch - 190ms/step
# Epoch 63/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8536266038229903
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.870530012771392
# 115/115 - 22s - loss: 0.4141 - auc: 0.8916 - val_loss: 0.5954 - val_auc: 0.8539 - 22s/epoch - 187ms/step
# Epoch 64/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8531129776220112
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8818047573435506
# 115/115 - 21s - loss: 0.4107 - auc: 0.8941 - val_loss: 0.6153 - val_auc: 0.8531 - 21s/epoch - 186ms/step
# Epoch 65/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8553185489556268
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8751795977011494
# 115/115 - 22s - loss: 0.4116 - auc: 0.8903 - val_loss: 0.6354 - val_auc: 0.8552 - 22s/epoch - 195ms/step
# Epoch 66/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8533446129675508
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.873184067688378
# 115/115 - 22s - loss: 0.4040 - auc: 0.8963 - val_loss: 0.6011 - val_auc: 0.8534 - 22s/epoch - 193ms/step
# Epoch 67/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8475436582270831
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8656609195402298
# 115/115 - 22s - loss: 0.4304 - auc: 0.8807 - val_loss: 0.6368 - val_auc: 0.8478 - 22s/epoch - 194ms/step
# Epoch 68/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8549559892843475
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8744612068965517
# 115/115 - 22s - loss: 0.4077 - auc: 0.8935 - val_loss: 0.6164 - val_auc: 0.8550 - 22s/epoch - 195ms/step
# Epoch 69/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8541301589219892
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8658604725415069
# 115/115 - 23s - loss: 0.4015 - auc: 0.8982 - val_loss: 0.6436 - val_auc: 0.8544 - 23s/epoch - 197ms/step
# Epoch 70/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8530626221121116
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8729246487867178
# 115/115 - 22s - loss: 0.4081 - auc: 0.8939 - val_loss: 0.6062 - val_auc: 0.8535 - 22s/epoch - 192ms/step
# Epoch 71/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8606159485970954
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8809067688378034
# 115/115 - 22s - loss: 0.4160 - auc: 0.8895 - val_loss: 0.6017 - val_auc: 0.8605 - 22s/epoch - 193ms/step
# Epoch 72/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8607670151267952
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8716674648786719
# 115/115 - 22s - loss: 0.3922 - auc: 0.9031 - val_loss: 0.6092 - val_auc: 0.8609 - 22s/epoch - 193ms/step
# Epoch 73/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8571514895159829
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.873742816091954
# ...
#   app.launch_new_instance()
#  | test_auc: 0.8498243500953528
# 115/115 - 22s - loss: 0.3407 - auc: 0.9267 - val_loss: 0.5143 - val_auc: 0.8409 - 22s/epoch - 190ms/step
# Epoch 128/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8477584866545737
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8582956940680517
# 115/115 - 22s - loss: 0.3468 - auc: 0.9244 - val_loss: 0.4979 - val_auc: 0.8477 - 22s/epoch - 192ms/step
# Epoch 129/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8546056172384237
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8651410217805882
# 115/115 - 22s - loss: 0.3352 - auc: 0.9293 - val_loss: 0.4975 - val_auc: 0.8542 - 22s/epoch - 194ms/step
# Epoch 130/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8522833735324018
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8597209675800461
# 115/115 - 22s - loss: 0.3292 - auc: 0.9327 - val_loss: 0.4991 - val_auc: 0.8522 - 22s/epoch - 192ms/step
# Epoch 131/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8621504176051986
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8602428987252836
# 115/115 - 22s - loss: 0.3292 - auc: 0.9319 - val_loss: 0.4917 - val_auc: 0.8620 - 22s/epoch - 195ms/step
# Epoch 132/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8515558036159228
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8548228445247416
# 115/115 - 22s - loss: 0.3414 - auc: 0.9258 - val_loss: 0.4984 - val_auc: 0.8512 - 22s/epoch - 191ms/step
# Epoch 133/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.867731775868599
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8656428786510088
# 115/115 - 21s - loss: 0.3506 - auc: 0.9230 - val_loss: 0.4999 - val_auc: 0.8674 - 21s/epoch - 186ms/step
# Epoch 134/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8559311898259814
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8565693064338051
# 115/115 - 22s - loss: 0.3356 - auc: 0.9294 - val_loss: 0.4884 - val_auc: 0.8555 - 22s/epoch - 189ms/step
# Epoch 135/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8619112165367673
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8607046070460704
# 115/115 - 23s - loss: 0.3497 - auc: 0.9229 - val_loss: 0.4864 - val_auc: 0.8619 - 23s/epoch - 196ms/step
# Epoch 136/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.848336555903283
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8517314062029508
# 115/115 - 22s - loss: 0.3523 - auc: 0.9228 - val_loss: 0.4939 - val_auc: 0.8484 - 22s/epoch - 192ms/step
# Epoch 137/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8614926146670121
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8592191107096255
# 115/115 - 22s - loss: 0.3422 - auc: 0.9269 - val_loss: 0.4893 - val_auc: 0.8613 - 22s/epoch - 192ms/step
# Epoch 138/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8623497518288915
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8625112917795844
# 115/115 - 22s - loss: 0.3395 - auc: 0.9279 - val_loss: 0.4850 - val_auc: 0.8623 - 22s/epoch - 193ms/step
# Epoch 139/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8607949448840873
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8633142627722574
# 115/115 - 22s - loss: 0.3302 - auc: 0.9321 - val_loss: 0.4798 - val_auc: 0.8609 - 22s/epoch - 195ms/step
# Epoch 140/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.862170351027568
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8654822844524742
# 115/115 - 22s - loss: 0.3291 - auc: 0.9315 - val_loss: 0.4835 - val_auc: 0.8622 - 22s/epoch - 193ms/step
# Epoch 141/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8510873681902447
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8581150255947003
# 115/115 - 22s - loss: 0.3376 - auc: 0.9288 - val_loss: 0.5037 - val_auc: 0.8509 - 22s/epoch - 192ms/step
# Epoch 142/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.854177048657484
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8467128374987453
# 115/115 - 22s - loss: 0.3335 - auc: 0.9302 - val_loss: 0.4928 - val_auc: 0.8540 - 22s/epoch - 190ms/step
# Epoch 143/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8571072617457693
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8546020275017565
# 115/115 - 22s - loss: 0.3413 - auc: 0.9267 - val_loss: 0.4813 - val_auc: 0.8570 - 22s/epoch - 193ms/step
# Epoch 144/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8509179341001057
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.853538090936465
# 115/115 - 21s - loss: 0.3383 - auc: 0.9282 - val_loss: 0.4969 - val_auc: 0.8509 - 21s/epoch - 186ms/step
# Epoch 145/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8587418023800506
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8640369366656631
# 115/115 - 22s - loss: 0.3352 - auc: 0.9291 - val_loss: 0.4890 - val_auc: 0.8587 - 22s/epoch - 192ms/step
# Epoch 146/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8594494388741604
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8664659239184984
# 115/115 - 23s - loss: 0.3296 - auc: 0.9319 - val_loss: 0.4862 - val_auc: 0.8593 - 23s/epoch - 196ms/step
# Epoch 147/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8614826479558275
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.86235069758105
# 115/115 - 23s - loss: 0.3135 - auc: 0.9384 - val_loss: 0.4870 - val_auc: 0.8615 - 23s/epoch - 198ms/step
# Epoch 148/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8531504774054658
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8431998394058015
# 115/115 - 22s - loss: 0.3331 - auc: 0.9314 - val_loss: 0.4952 - val_auc: 0.8530 - 22s/epoch - 193ms/step
# Epoch 149/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8548946518627782
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.857593094449463
# 115/115 - 22s - loss: 0.3154 - auc: 0.9389 - val_loss: 0.4875 - val_auc: 0.8547 - 22s/epoch - 194ms/step
# Epoch 150/150
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8517053042836925
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.852173040248921
# 115/115 - 22s - loss: 0.3320 - auc: 0.9312 - val_loss: 0.4966 - val_auc: 0.8512 - 22s/epoch - 195ms/step
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:71: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.5077905058860779 , AUC = 0.8521530628204346
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:80: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8517053042836925
# test 0.852173040248921
#
# -----------------------------------------------------------------

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {0: '/content/models/150/0/016--0.469--0.506.hdf5',
          1: '/content/models/150/1/145--0.442--0.315.hdf5',
          2: '/content/models/150/2/136--0.453--0.336.hdf5',
          3: '/content/models/150/3/031--0.471--0.460.hdf5',
          4: '/content/models/150/4/062--0.467--0.421.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(5):
  print(iii)


  test_features= DATA[RUN]['MFCCS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_extra   = DATA[RUN]['EXTRA'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_imgs    = DATA[RUN]['MEL'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_labels  = DATA[RUN]['LABELS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
                                        
                                        
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=32,target_size=(224,224))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)
  

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 448
# acc:  0.8058035714285714
# 1
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Num_samples: 448
# acc:  0.9308035714285714
# 2
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Num_samples: 448
# acc:  0.8973214285714286
# 3
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Num_samples: 448
# acc:  0.8214285714285714
# 4
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Num_samples: 448
# acc:  0.7879464285714286
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {0: '/content/models/150/0/016--0.469--0.506.hdf5',
          1: '/content/models/150/1/145--0.442--0.315.hdf5',
          2: '/content/models/150/2/136--0.453--0.336.hdf5',
          3: '/content/models/150/3/031--0.471--0.460.hdf5',
          4: '/content/models/150/4/062--0.467--0.421.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(5):
  print(iii)

  test_features= DATA[RUN]['MFCCS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_extra   = DATA[RUN]['EXTRA'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_imgs    = DATA[RUN]['MEL'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_labels  = DATA[RUN]['LABELS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=32,target_size=(224,224))

                                     
  val_features= DATA[RUN]['MFCCS'][ int(0.9*len(data_x)) :]
  val_extra   = DATA[RUN]['EXTRA'][ int(0.9*len(data_x)) :]
  val_imgs    = DATA[RUN]['MEL'][ int(0.9*len(data_x)) :]
  val_labels  = DATA[RUN]['LABELS'][ int(0.9*len(data_x)) :]
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=32,target_size=(224,224))


  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)
    

  MERGM_Record1 = model.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = model.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = model.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.savefig('ConfusionMatrix.png')
  plt.show()

  

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 448
# acc:  0.8058035714285714
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.4257136881351471 , AUC = 0.8966576457023621
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8713995255845476
# test 0.8966977817926327
#
# -----------------------------------------------------------------
# 1
# Num_samples: 448
# acc:  0.9308035714285714
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.24027879536151886 , AUC = 0.978209376335144
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.9613590607371381
# test 0.978319783197832
#
# -----------------------------------------------------------------
# 2
# Num_samples: 448
# acc:  0.8973214285714286
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.2952860891819 , AUC = 0.9608149528503418
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.9559571032750613
# test 0.9607949412827461
#
# -----------------------------------------------------------------
# 3
# Num_samples: 448
# acc:  0.8214285714285714
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.3927586078643799 , AUC = 0.9188598394393921
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.892648553830207
# test 0.9190003011141221
#
# -----------------------------------------------------------------
# 4
# Num_samples: 448
# acc:  0.7879464285714286
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.46300506591796875 , AUC = 0.8680116534233093
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8605358103932864
# test 0.8681320887282947
#
# -----------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:87: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {
    #0: '/content/models/150/0/016--0.469--0.506.hdf5',
          0: '/content/models/150/1/145--0.442--0.315.hdf5'
     ##    3: '/content/models/150/3/031--0.471--0.460.hdf5',
       #   4: '/content/models/150/4/062--0.467--0.421.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(1):
  print(iii)

  test_features= DATA[RUN]['MFCCS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_extra   = DATA[RUN]['EXTRA'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_imgs    = DATA[RUN]['MEL'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  test_labels  = DATA[RUN]['LABELS'][ int(0.8*len(data_x)): int(0.9*len(data_x))]
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=32,target_size=(224,224))

                                     
  val_features= DATA[RUN]['MFCCS'][ int(0.9*len(data_x)) :]
  val_extra   = DATA[RUN]['EXTRA'][ int(0.9*len(data_x)) :]
  val_imgs    = DATA[RUN]['MEL'][ int(0.9*len(data_x)) :]
  val_labels  = DATA[RUN]['LABELS'][ int(0.9*len(data_x)) :]
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=32,target_size=(224,224))


  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)
    

  MERGM_Record1 = model.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = model.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = model.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.savefig('ConfusionMatrix.png')
  plt.show()

  

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 448
# acc:  0.9308035714285714
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.24027879536151886 , AUC = 0.978209376335144
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.9613590607371381
# test 0.978319783197832
#
# -----------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:87: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp -r "/content/first-model/" "/content/drive/"
